# %%
from lxml import etree as parser

# %%
import xmltodict as parser

# %%
import pandas
from io import StringIO

# %%
import json

# %%
doc = parser.parse(open("/tmp/named_download.xml",'rb'))

# %%
doc
# Out:
# OrderedDict([('opt',
#               OrderedDict([('@XMLDecl',
#                             "<?xml version='1.0' encoding='utf-8'?>"),
#                            ('data',
#                             OrderedDict([('@name', 'orthoXML'),
#                                          ('@origin', 'ortholugeDB'),
#                                          ('@originVersion', '1.0'),
#                                          ('@version', '0.3'),
#                                          ('@xmlns',
#                                           'http://orthoXML.org/2011/'),
#                                          ('@xmlns:xsi',
#                                           'http://www.w3.org/2001/XMLSchema-instance'),
#                                          ('@xsi:schemaLocation',
#                                           'http://www.orthoxml.org/0.3/orthoxml.xsd'),
#                                          ('groups',
#                                           OrderedDict([('orthologGroup',
#                                                         [OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1543887')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1500226')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1958096')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1578350')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1672101')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '253031')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '33859')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1484840')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1466562')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '54064')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1609098')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1823053')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1880961')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1733455')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1647749')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1466562')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1659448')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1466562')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1723631')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1683962')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1548835')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1902555')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1466562')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1441019')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1599145')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1505746')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1448209')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '104476')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1466562')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1516335')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1869022')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1711723')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1946082')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1852881')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1466562')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1837372')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1466562')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1833241')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '770340')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '49799')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1693655')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1527464')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1751024')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1569819')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1915399')])])]),
#                                                          OrderedDict([('geneRef',
#                                                                        [OrderedDict([('@id',
#                                                                                       '1466562')]),
#                                                                         OrderedDict([('@id',
#                                                                                       '1477480')])])])])])),
#                                          ('notes',
#                                           'This is an example OrthoXML file'),
#                                          ('species',
#                                           [OrderedDict([('@name',
#                                                          'Pseudomonas fluorescens SBW25'),
#                                                         ('@GenomeProjectId',
#                                                          '116'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1466562'),
#                                                                                     ('@geneId',
#                                                                                      '229591727')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas putida BIRD-1'),
#                                                         ('@GenomeProjectId',
#                                                          '170'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1543887'),
#                                                                                     ('@geneId',
#                                                                                      '386013367')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas fluorescens SBW25'),
#                                                         ('@GenomeProjectId',
#                                                          '116'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1466562'),
#                                                                                     ('@geneId',
#                                                                                      '229591727')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas putida F1'),
#                                                         ('@GenomeProjectId',
#                                                          '118'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1500226'),
#                                                                                     ('@geneId',
#                                                                                      '148549159')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas denitrificans ATCC 13867'),
#                                                         ('@GenomeProjectId',
#                                                          '198'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1958096'),
#                                                                                     ('@geneId',
#                                                                                      '472324834')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas putida HB3267'),
#                                                         ('@GenomeProjectId',
#                                                          '188'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1578350'),
#                                                                                     ('@geneId',
#                                                                                      '431801316')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas aeruginosa PA7'),
#                                                         ('@GenomeProjectId',
#                                                          '119'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1672101'),
#                                                                                     ('@geneId',
#                                                                                      '152986044')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas aeruginosa LESB58'),
#                                                         ('@GenomeProjectId',
#                                                          '125'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '253031'),
#                                                                                     ('@geneId',
#                                                                                      '218893172')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas aeruginosa 2192'),
#                                                         ('@GenomeProjectId',
#                                                          '82'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '33859'),
#                                                                                     ('@geneId',
#                                                                                      '254245147')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas putida KT2440'),
#                                                         ('@GenomeProjectId',
#                                                          '110'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1484840'),
#                                                                                     ('@geneId',
#                                                                                      '26988492')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas aeruginosa PACS2'),
#                                                         ('@GenomeProjectId',
#                                                          '84'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '54064'),
#                                                                                     ('@geneId',
#                                                                                      '107100318')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas putida H8234'),
#                                                         ('@GenomeProjectId',
#                                                          '190'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1609098'),
#                                                                                     ('@geneId',
#                                                                                      '512577181')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas mendocina ymp'),
#                                                         ('@GenomeProjectId',
#                                                          '120'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1823053'),
#                                                                                     ('@geneId',
#                                                                                      '146309385')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas sp. UW4'),
#                                                         ('@GenomeProjectId',
#                                                          '194'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1880961'),
#                                                                                     ('@geneId',
#                                                                                      '426408262')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas aeruginosa RP73'),
#                                                         ('@GenomeProjectId',
#                                                          '192'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1733455'),
#                                                                                     ('@geneId',
#                                                                                      '514408392')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas syringae pv. syringae B728a'),
#                                                         ('@GenomeProjectId',
#                                                          '112'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1647749'),
#                                                                                     ('@geneId',
#                                                                                      '66046884')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas aeruginosa UCBPP-PA14'),
#                                                         ('@GenomeProjectId',
#                                                          '109'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1659448'),
#                                                                                     ('@geneId',
#                                                                                      '116048784')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas aeruginosa B136-33'),
#                                                         ('@GenomeProjectId',
#                                                          '191'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1723631'),
#                                                                                     ('@geneId',
#                                                                                      '478480398')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas aeruginosa M18'),
#                                                         ('@GenomeProjectId',
#                                                          '172'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1683962'),
#                                                                                     ('@geneId',
#                                                                                      '386060240')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas putida ND6'),
#                                                         ('@GenomeProjectId',
#                                                          '187'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1548835'),
#                                                                                     ('@geneId',
#                                                                                      '395444848')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas protegens Pf-5'),
#                                                         ('@GenomeProjectId',
#                                                          '113'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1902555'),
#                                                                                     ('@geneId',
#                                                                                      '70731672')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas fluorescens Pf0-1'),
#                                                         ('@GenomeProjectId',
#                                                          '124'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1441019'),
#                                                                                     ('@geneId',
#                                                                                      '77460307')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas putida NBRC 14164'),
#                                                         ('@GenomeProjectId',
#                                                          '189'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1599145'),
#                                                                                     ('@geneId',
#                                                                                      '512687067')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas putida W619'),
#                                                         ('@GenomeProjectId',
#                                                          '122'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
# ...
#                                                                        OrderedDict([('@id',
#                                                                                      '1869022'),
#                                                                                     ('@geneId',
#                                                                                      '330808279')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas aeruginosa DK2'),
#                                                         ('@GenomeProjectId',
#                                                          '174'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1711723'),
#                                                                                     ('@geneId',
#                                                                                      '392985662')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas poae RE*1-1-14'),
#                                                         ('@GenomeProjectId',
#                                                          '197'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1946082'),
#                                                                                     ('@geneId',
#                                                                                      '447917497')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas syringae pv. phaseolicola 1448A'),
#                                                         ('@GenomeProjectId',
#                                                          '114'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1852881'),
#                                                                                     ('@geneId',
#                                                                                      '71738020')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas syringae pv. tomato str. DC3000'),
#                                                         ('@GenomeProjectId',
#                                                          '111'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1837372'),
#                                                                                     ('@geneId',
#                                                                                      '28868943')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas mendocina NK-01'),
#                                                         ('@GenomeProjectId',
#                                                          '160'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1833241'),
#                                                                                     ('@geneId',
#                                                                                      '330505615')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas aeruginosa 39016'),
#                                                         ('@GenomeProjectId',
#                                                          '153'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '770340'),
#                                                                                     ('@geneId',
#                                                                                      '313105738')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas aeruginosa C3719'),
#                                                         ('@GenomeProjectId',
#                                                          '81'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '49799'),
#                                                                                     ('@geneId',
#                                                                                      '254239213')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas aeruginosa NCGM2.S1'),
#                                                         ('@GenomeProjectId',
#                                                          '173'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1693655'),
#                                                                                     ('@geneId',
#                                                                                      '386064581')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas putida S16'),
#                                                         ('@GenomeProjectId',
#                                                          '169'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1527464'),
#                                                                                     ('@geneId',
#                                                                                      '339486329')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas entomophila L48'),
#                                                         ('@GenomeProjectId',
#                                                          '117'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1751024'),
#                                                                                     ('@geneId',
#                                                                                      '104780661')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas putida DOT-T1E'),
#                                                         ('@GenomeProjectId',
#                                                          '171'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1569819'),
#                                                                                     ('@geneId',
#                                                                                      '397695758')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas protegens CHA0'),
#                                                         ('@GenomeProjectId',
#                                                          '195'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1915399'),
#                                                                                     ('@geneId',
#                                                                                      '501681831')]))]))]),
#                                            OrderedDict([('@name',
#                                                          'Pseudomonas fluorescens A506'),
#                                                         ('@GenomeProjectId',
#                                                          '168'),
#                                                         ('database',
#                                                          OrderedDict([('@name',
#                                                                        'NCBI'),
#                                                                       ('@geneLink',
#                                                                        'http://www.ncbi.nlm.nih.gov/protein/'),
#                                                                       ('genes',
#                                                                        OrderedDict([('@id',
#                                                                                      '1477480'),
#                                                                                     ('@geneId',
#                                                                                      '387894765')]))]))])])]))]))])

# %%
json.dumps(doc)
# Out:
# '{"opt": {"@XMLDecl": "<?xml version=\'1.0\' encoding=\'utf-8\'?>", "data": {"@name": "orthoXML", "@origin": "ortholugeDB", "@originVersion": "1.0", "@version": "0.3", "@xmlns": "http://orthoXML.org/2011/", "@xmlns:xsi": "http://www.w3.org/2001/XMLSchema-instance", "@xsi:schemaLocation": "http://www.orthoxml.org/0.3/orthoxml.xsd", "groups": {"orthologGroup": [{"geneRef": [{"@id": "1466562"}, {"@id": "1543887"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1500226"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1958096"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1578350"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1672101"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "253031"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "33859"}]}, {"geneRef": [{"@id": "1484840"}, {"@id": "1466562"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "54064"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1609098"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1823053"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1880961"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1733455"}]}, {"geneRef": [{"@id": "1647749"}, {"@id": "1466562"}]}, {"geneRef": [{"@id": "1659448"}, {"@id": "1466562"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1723631"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1683962"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1548835"}]}, {"geneRef": [{"@id": "1902555"}, {"@id": "1466562"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1441019"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1599145"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1505746"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1448209"}]}, {"geneRef": [{"@id": "104476"}, {"@id": "1466562"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1516335"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1869022"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1711723"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1946082"}]}, {"geneRef": [{"@id": "1852881"}, {"@id": "1466562"}]}, {"geneRef": [{"@id": "1837372"}, {"@id": "1466562"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1833241"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "770340"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "49799"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1693655"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1527464"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1751024"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1569819"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1915399"}]}, {"geneRef": [{"@id": "1466562"}, {"@id": "1477480"}]}]}, "notes": "This is an example OrthoXML file", "species": [{"@name": "Pseudomonas fluorescens SBW25", "@GenomeProjectId": "116", "database": {"@name": "NCBI", "@geneLink": "http://www.ncbi.nlm.nih.gov/protein/", "genes": {"@id": "1466562", "@geneId": "229591727"}}}, {"@name": "Pseudomonas putida BIRD-1", "@GenomeProjectId": "170", "database": {"@name": "NCBI", "@geneLink": "http://www.ncbi.nlm.nih.gov/protein/", "genes": {"@id": "1543887", "@geneId": "386013367"}}}, {"@name": "Pseudomonas fluorescens SBW25", "@GenomeProjectId": "116", "database": {"@name": "NCBI", "@geneLink": "http://www.ncbi.nlm.nih.gov/protein/", "genes": {"@id": "1466562", "@geneId": "229591727"}}}, {"@name": "Pseudomonas putida F1", "@GenomeProjectId": "118", "database": {"@name": "NCBI", "@geneLink": "http://www.ncbi.nlm.nih.gov/protein/", "genes": {"@id": "1500226", "@geneId": "148549159"}}}, {"@name": "Pseudomonas denitrificans ATCC 13867", "@GenomeProjectId": "198", "database": {"@name": "NCBI", "@geneLink": "http://www.ncbi.nlm.nih.gov/protein/", "genes": {"@id": "1958096", "@geneId": "472324834"}}}, {"@name": "Pseudomonas putida HB3267", "@GenomeProjectId": "188", "database": {"@name": "NCBI", "@geneLink": "http://www.ncbi.nlm.nih.gov/protein/", "genes": {"@id": "1578350", "@geneId": "431801316"}}}, {"@name": "Pseudomonas aeruginosa PA7", "@GenomeProjectId": "119", "database": {"@name": "NCBI", "@geneLink": "http://www.ncbi.nlm.nih.gov/protein/", "genes": {"@id": "1672101", "@geneId": "152986044"}}}, ...

# %%
doc = json.loads(json.dumps(doc))

# %%
from IPython.display import JSON

# %%
JSON(filename='/tmp/named_download.xml')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-15-cf0295b37ef5> in <module>
# ----> 1 JSON(filename='/tmp/named_download.xml')
#
# ~/.conda/envs/pflu/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, expanded, metadata, root, **kwargs)
#     852         if kwargs:
#     853             self.metadata.update(kwargs)
# --> 854         super(JSON, self).__init__(data=data, url=url, filename=filename)
#     855
#     856     def _check_data(self):
#
# ~/.conda/envs/pflu/lib/python3.7/site-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     613             self.metadata = {}
#     614
# --> 615         self.reload()
#     616         self._check_data()
#     617
#
# ~/.conda/envs/pflu/lib/python3.7/site-packages/IPython/core/display.py in reload(self)
#     639         if self.filename is not None:
#     640             with open(self.filename, self._read_flags) as f:
# --> 641                 self.data = f.read()
#     642         elif self.url is not None:
#     643             try:
#
# ~/.conda/envs/pflu/lib/python3.7/site-packages/IPython/core/display.py in data(self, data)
#     867             if getattr(self, 'filename', None) is None:
#     868                 warnings.warn("JSON expects JSONable dict or list, not JSON strings")
# --> 869             data = json.loads(data)
#     870         self._data = data
#     871
#
# ~/.conda/envs/pflu/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/.conda/envs/pflu/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/.conda/envs/pflu/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
doc
# Out:
# {'opt': {'@XMLDecl': "<?xml version='1.0' encoding='utf-8'?>",
#   'data': {'@name': 'orthoXML',
#    '@origin': 'ortholugeDB',
#    '@originVersion': '1.0',
#    '@version': '0.3',
#    '@xmlns': 'http://orthoXML.org/2011/',
#    '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance',
#    '@xsi:schemaLocation': 'http://www.orthoxml.org/0.3/orthoxml.xsd',
#    'groups': {'orthologGroup': [{'geneRef': [{'@id': '1466562'},
#        {'@id': '1543887'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1500226'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1958096'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1578350'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1672101'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '253031'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '33859'}]},
#      {'geneRef': [{'@id': '1484840'}, {'@id': '1466562'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '54064'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1609098'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1823053'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1880961'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1733455'}]},
#      {'geneRef': [{'@id': '1647749'}, {'@id': '1466562'}]},
#      {'geneRef': [{'@id': '1659448'}, {'@id': '1466562'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1723631'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1683962'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1548835'}]},
#      {'geneRef': [{'@id': '1902555'}, {'@id': '1466562'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1441019'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1599145'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1505746'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1448209'}]},
#      {'geneRef': [{'@id': '104476'}, {'@id': '1466562'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1516335'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1869022'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1711723'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1946082'}]},
#      {'geneRef': [{'@id': '1852881'}, {'@id': '1466562'}]},
#      {'geneRef': [{'@id': '1837372'}, {'@id': '1466562'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1833241'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '770340'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '49799'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1693655'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1527464'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1751024'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1569819'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1915399'}]},
#      {'geneRef': [{'@id': '1466562'}, {'@id': '1477480'}]}]},
#    'notes': 'This is an example OrthoXML file',
#    'species': [{'@name': 'Pseudomonas fluorescens SBW25',
#      '@GenomeProjectId': '116',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1466562', '@geneId': '229591727'}}},
#     {'@name': 'Pseudomonas putida BIRD-1',
#      '@GenomeProjectId': '170',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1543887', '@geneId': '386013367'}}},
#     {'@name': 'Pseudomonas fluorescens SBW25',
#      '@GenomeProjectId': '116',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1466562', '@geneId': '229591727'}}},
#     {'@name': 'Pseudomonas putida F1',
#      '@GenomeProjectId': '118',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1500226', '@geneId': '148549159'}}},
#     {'@name': 'Pseudomonas denitrificans ATCC 13867',
#      '@GenomeProjectId': '198',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1958096', '@geneId': '472324834'}}},
#     {'@name': 'Pseudomonas putida HB3267',
#      '@GenomeProjectId': '188',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1578350', '@geneId': '431801316'}}},
#     {'@name': 'Pseudomonas aeruginosa PA7',
#      '@GenomeProjectId': '119',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1672101', '@geneId': '152986044'}}},
#     {'@name': 'Pseudomonas aeruginosa LESB58',
#      '@GenomeProjectId': '125',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '253031', '@geneId': '218893172'}}},
#     {'@name': 'Pseudomonas aeruginosa 2192',
#      '@GenomeProjectId': '82',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '33859', '@geneId': '254245147'}}},
#     {'@name': 'Pseudomonas putida KT2440',
#      '@GenomeProjectId': '110',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1484840', '@geneId': '26988492'}}},
#     {'@name': 'Pseudomonas aeruginosa PACS2',
#      '@GenomeProjectId': '84',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '54064', '@geneId': '107100318'}}},
#     {'@name': 'Pseudomonas putida H8234',
#      '@GenomeProjectId': '190',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1609098', '@geneId': '512577181'}}},
#     {'@name': 'Pseudomonas mendocina ymp',
#      '@GenomeProjectId': '120',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1823053', '@geneId': '146309385'}}},
#     {'@name': 'Pseudomonas sp. UW4',
#      '@GenomeProjectId': '194',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1880961', '@geneId': '426408262'}}},
#     {'@name': 'Pseudomonas aeruginosa RP73',
#      '@GenomeProjectId': '192',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1733455', '@geneId': '514408392'}}},
#     {'@name': 'Pseudomonas syringae pv. syringae B728a',
#      '@GenomeProjectId': '112',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1647749', '@geneId': '66046884'}}},
#     {'@name': 'Pseudomonas aeruginosa UCBPP-PA14',
#      '@GenomeProjectId': '109',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1659448', '@geneId': '116048784'}}},
#     {'@name': 'Pseudomonas aeruginosa B136-33',
#      '@GenomeProjectId': '191',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1723631', '@geneId': '478480398'}}},
#     {'@name': 'Pseudomonas aeruginosa M18',
#      '@GenomeProjectId': '172',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1683962', '@geneId': '386060240'}}},
#     {'@name': 'Pseudomonas putida ND6',
#      '@GenomeProjectId': '187',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1548835', '@geneId': '395444848'}}},
#     {'@name': 'Pseudomonas protegens Pf-5',
#      '@GenomeProjectId': '113',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1902555', '@geneId': '70731672'}}},
#     {'@name': 'Pseudomonas fluorescens Pf0-1',
#      '@GenomeProjectId': '124',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1441019', '@geneId': '77460307'}}},
#     {'@name': 'Pseudomonas putida NBRC 14164',
#      '@GenomeProjectId': '189',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1599145', '@geneId': '512687067'}}},
#     {'@name': 'Pseudomonas putida W619',
#      '@GenomeProjectId': '122',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1505746', '@geneId': '170720554'}}},
#     {'@name': 'Pseudomonas fluorescens F113',
#      '@GenomeProjectId': '167',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1448209', '@geneId': '378949559'}}},
#     {'@name': 'Pseudomonas aeruginosa PAO1',
#      '@GenomeProjectId': '107',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '104476', '@geneId': '15596058'}}},
#     {'@name': 'Pseudomonas putida GB-1',
#      '@GenomeProjectId': '121',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1516335', '@geneId': '167032364'}}},
#     {'@name': 'Pseudomonas brassicacearum subsp. brassicacearum NFM421',
#      '@GenomeProjectId': '158',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1869022', '@geneId': '330808279'}}},
#     {'@name': 'Pseudomonas aeruginosa DK2',
#      '@GenomeProjectId': '174',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1711723', '@geneId': '392985662'}}},
#     {'@name': 'Pseudomonas poae RE*1-1-14',
#      '@GenomeProjectId': '197',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1946082', '@geneId': '447917497'}}},
#     {'@name': 'Pseudomonas syringae pv. phaseolicola 1448A',
#      '@GenomeProjectId': '114',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1852881', '@geneId': '71738020'}}},
#     {'@name': 'Pseudomonas syringae pv. tomato str. DC3000',
#      '@GenomeProjectId': '111',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1837372', '@geneId': '28868943'}}},
#     {'@name': 'Pseudomonas mendocina NK-01',
#      '@GenomeProjectId': '160',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1833241', '@geneId': '330505615'}}},
#     {'@name': 'Pseudomonas aeruginosa 39016',
#      '@GenomeProjectId': '153',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '770340', '@geneId': '313105738'}}},
#     {'@name': 'Pseudomonas aeruginosa C3719',
#      '@GenomeProjectId': '81',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '49799', '@geneId': '254239213'}}},
#     {'@name': 'Pseudomonas aeruginosa NCGM2.S1',
#      '@GenomeProjectId': '173',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1693655', '@geneId': '386064581'}}},
#     {'@name': 'Pseudomonas putida S16',
#      '@GenomeProjectId': '169',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1527464', '@geneId': '339486329'}}},
#     {'@name': 'Pseudomonas entomophila L48',
#      '@GenomeProjectId': '117',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1751024', '@geneId': '104780661'}}},
#     {'@name': 'Pseudomonas putida DOT-T1E',
#      '@GenomeProjectId': '171',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1569819', '@geneId': '397695758'}}},
#     {'@name': 'Pseudomonas protegens CHA0',
#      '@GenomeProjectId': '195',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1915399', '@geneId': '501681831'}}},
#     {'@name': 'Pseudomonas fluorescens A506',
#      '@GenomeProjectId': '168',
#      'database': {'@name': 'NCBI',
#       '@geneLink': 'http://www.ncbi.nlm.nih.gov/protein/',
#       'genes': {'@id': '1477480', '@geneId': '387894765'}}}]}}}

# %%
JSON(json.loads('{"a": [{"aa": 1, "bb":2}, {"cc":3, "dd":4}],"b": 5}'))
