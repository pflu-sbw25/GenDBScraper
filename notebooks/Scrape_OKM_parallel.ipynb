# %% [markdown]
# # Get knowledge maps for all genes in SBW25

# %%
idx_lo = 800
idx_hi = 1058

# %%
import pandas, numpy

from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions
import logging

# %%
def query_okm(idx):

    gene = gene_names.loc[idx]
    logging.info("Querying %s aka %s", gene, idx)
    search_box = driver.find_element_by_id("searchterm")
    search_box.clear()
    search_box.send_keys(gene)
                         
    search_box.submit()
    
    driver.switch_to.window(window_name=driver.window_handles[1])
    
    try:
        element = WebDriverWait(driver, 60).until(
            expected_conditions.presence_of_element_located((By.ID, "chart_canvas"))
        )
    
        okm_url = driver.current_url
        
        
        logging.info("url = %s", okm_url)
        
     
    
    except:
        logging.error("No map found after waiting for 60 seconds")
        
        okm_url = None
       
        
    finally:
        driver.close()
        driver.switch_to.window(window_name=driver.window_handles[0])
        
        return okm_url

# %%
logging.getLogger().setLevel(logging.INFO)

# %%
features = pandas.read_csv("/opt/data/sbw25/features.csv")

# %%
gene_names = features["Gene Name"]

gene_names.index = features["Locus Tag"]

non_nan_tags = [t for t in gene_names.index if isinstance(gene_names.loc[t], str)]

gene_names = gene_names.loc[non_nan_tags]

# %%
len(gene_names)
# Out:
# 1058

# %%
gene_names = gene_names.iloc[idx_lo:idx_hi]

# %%
len(gene_names)
# Out:
# 258

# %%
okm_urls = pandas.Series(index = gene_names.index, data=[None]*len(gene_names))

# %%
driver = webdriver.Firefox()

# %%
driver.get('https://openknowledgemaps.org')

# %% [markdown]
# ### Break here

# %%
for i,locus_tag in enumerate(gene_names.index):
    logging.info("Processing index #%d => locus tag %s", i, locus_tag)
    okm_urls.loc[locus_tag] = query_okm(locus_tag)
# Out:
# INFO:root:Processing index #0 => locus tag PFLU5340
# INFO:root:Querying mscL aka PFLU5340
# INFO:root:url = https://openknowledgemaps.org/map/c0accfa66eec22744edcde6d49b33b8d
# INFO:root:Processing index #1 => locus tag PFLU5341
# INFO:root:Querying fpr aka PFLU5341
# INFO:root:url = https://openknowledgemaps.org/map/2f834feac413890c835d0df60d738248
# INFO:root:Processing index #2 => locus tag PFLU5353
# INFO:root:Querying trmA aka PFLU5353
# INFO:root:url = https://openknowledgemaps.org/map/c2f3d2b71e3826c342b39195bdfbb682
# INFO:root:Processing index #3 => locus tag PFLU5364
# INFO:root:Querying aroQ aka PFLU5364
# INFO:root:url = https://openknowledgemaps.org/map/73c954e23466b2d2471b1cd168c1651e
# INFO:root:Processing index #4 => locus tag PFLU5365
# INFO:root:Querying aroE aka PFLU5365
# INFO:root:url = https://openknowledgemaps.org/map/0dcd859302b1228bdee4a4d7c9628a54
# INFO:root:Processing index #5 => locus tag PFLU5374
# INFO:root:Querying tesB aka PFLU5374
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #6 => locus tag PFLU5378
# INFO:root:Querying rhlE2 aka PFLU5378
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #7 => locus tag PFLU5389
# INFO:root:Querying hrpB aka PFLU5389
# INFO:root:url = https://openknowledgemaps.org/map/6dd3262e8e8a0e3f34d847be3451d08c
# INFO:root:Processing index #8 => locus tag PFLU5395
# INFO:root:Querying rluE aka PFLU5395
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #9 => locus tag PFLU5396
# INFO:root:Querying amn aka PFLU5396
# INFO:root:url = https://openknowledgemaps.org/map/75cba2b02c260e6de7ae1b7c981c8de1
# INFO:root:Processing index #10 => locus tag PFLU5400
# INFO:root:Querying thiE aka PFLU5400
# INFO:root:url = https://openknowledgemaps.org/map/a0fe1e7c00f511ab8c975bf149ad6f47
# INFO:root:Processing index #11 => locus tag PFLU5401
# INFO:root:Querying hemL aka PFLU5401
# INFO:root:url = https://openknowledgemaps.org/map/56e2604ebe0b229aded8f1b863149e38
# INFO:root:Processing index #12 => locus tag PFLU5407
# INFO:root:Querying corC aka PFLU5407
# INFO:root:url = https://openknowledgemaps.org/map/df0e97a9ff92f646b021c87e63d562f1
# INFO:root:Processing index #13 => locus tag PFLU5408
# INFO:root:Querying lnt aka PFLU5408
# INFO:root:url = https://openknowledgemaps.org/map/8cb8f2546c6bcb0de6e416cc9cb8dd8e
# INFO:root:Processing index #14 => locus tag PFLU5410
# INFO:root:Querying leuS aka PFLU5410
# INFO:root:url = https://openknowledgemaps.org/map/479ee49270fb0e09da30f2d99fce4041
# INFO:root:Processing index #15 => locus tag PFLU5412
# INFO:root:Querying holA aka PFLU5412
# INFO:root:url = https://openknowledgemaps.org/map/4bc9c5d6f8def989ef4dfcd9da847b1a
# INFO:root:Processing index #16 => locus tag PFLU5416
# INFO:root:Querying lipA aka PFLU5416
# INFO:root:url = https://openknowledgemaps.org/map/a398e30c8cec94b0bd3d60bf244cbd84
# INFO:root:Processing index #17 => locus tag PFLU5417
# INFO:root:Querying lipB aka PFLU5417
# INFO:root:url = https://openknowledgemaps.org/map/d202fa803187277796aab988c4796b8c
# INFO:root:Processing index #18 => locus tag PFLU5422
# INFO:root:Querying mrdB aka PFLU5422
# INFO:root:url = https://openknowledgemaps.org/map/e9d9fd4081c91388bc3a45924a266868
# INFO:root:Processing index #19 => locus tag PFLU5426
# INFO:root:Querying nadD aka PFLU5426
# INFO:root:url = https://openknowledgemaps.org/map/09faf634fb5534749f217dfb89d1a2e3
# INFO:root:Processing index #20 => locus tag PFLU5427
# INFO:root:Querying proA aka PFLU5427
# INFO:root:url = https://openknowledgemaps.org/map/2a7f521a83c41980c6b338732fc92a10
# INFO:root:Processing index #21 => locus tag PFLU5439
# INFO:root:Querying mpl aka PFLU5439
# INFO:root:url = https://openknowledgemaps.org/map/bd53661a88ec960915f23d8bbf310461
# INFO:root:Processing index #22 => locus tag PFLU5443
# INFO:root:Querying eutB aka PFLU5443
# INFO:root:url = https://openknowledgemaps.org/map/12e12dd0992f7f61be9b7cb5e80ca6cd
# INFO:root:Processing index #23 => locus tag PFLU5446
# INFO:root:Querying dedA aka PFLU5446
# INFO:root:url = https://openknowledgemaps.org/map/74683699776c792bdd46c04e9cf665a2
# INFO:root:Processing index #24 => locus tag PFLU5448
# INFO:root:Querying ppa aka PFLU5448
# INFO:root:url = https://openknowledgemaps.org/map/86815d30cd80fb9593a1bb53117b3244
# INFO:root:Processing index #25 => locus tag PFLU5460
# INFO:root:Querying xseB aka PFLU5460
# INFO:root:url = https://openknowledgemaps.org/map/56f240adf4ca5e4aec34c3248793c3a0
# INFO:root:Processing index #26 => locus tag PFLU5461
# INFO:root:Querying ispA aka PFLU5461
# INFO:root:url = https://openknowledgemaps.org/map/f083d7e3a7a0342aca15104e3daee002
# INFO:root:Processing index #27 => locus tag PFLU5462
# INFO:root:Querying dxs aka PFLU5462
# INFO:root:url = https://openknowledgemaps.org/map/67af0f12fcd560c452ff3c4072dc1989
# INFO:root:Processing index #28 => locus tag PFLU5466
# INFO:root:Querying ribA aka PFLU5466
# INFO:root:url = https://openknowledgemaps.org/map/055a4303aa835f8a2b029f7a17a634da
# INFO:root:Processing index #29 => locus tag PFLU5468
# INFO:root:Querying thiL aka PFLU5468
# INFO:root:url = https://openknowledgemaps.org/map/811e1fb0e09d4d00956480f426b41357
# INFO:root:Processing index #30 => locus tag PFLU5469
# INFO:root:Querying nusB aka PFLU5469
# INFO:root:url = https://openknowledgemaps.org/map/a64630ab4d5eb42ed3074d13cc037c9f
# INFO:root:Processing index #31 => locus tag PFLU5470
# INFO:root:Querying ribH aka PFLU5470
# INFO:root:url = https://openknowledgemaps.org/map/f4fab4ca25293009bb1d123a949890f2
# INFO:root:Processing index #32 => locus tag PFLU5471
# INFO:root:Querying ribB aka PFLU5471
# INFO:root:url = https://openknowledgemaps.org/map/10f713e4408756db63d94e5f733bdd08
# INFO:root:Processing index #33 => locus tag PFLU5472
# INFO:root:Querying ribE aka PFLU5472
# INFO:root:url = https://openknowledgemaps.org/map/b957e23d38698143f4a2293400ed38d4
# INFO:root:Processing index #34 => locus tag PFLU5473
# INFO:root:Querying ribD aka PFLU5473
# INFO:root:url = https://openknowledgemaps.org/map/4cbbeb4bac5259200000be7e2f6359c3
# INFO:root:Processing index #35 => locus tag PFLU5474
# INFO:root:Querying nrdR aka PFLU5474
# INFO:root:url = https://openknowledgemaps.org/map/30537aae95f5727e1a184c2fa4266089
# INFO:root:Processing index #36 => locus tag PFLU5494
# INFO:root:Querying tam aka PFLU5494
# INFO:root:url = https://openknowledgemaps.org/map/b4ec79900415626839b0fefec902220b
# INFO:root:Processing index #37 => locus tag PFLU5496
# INFO:root:Querying ssb aka PFLU5496
# INFO:root:url = https://openknowledgemaps.org/map/43da1d340b627bec56be1002fc890e82
# INFO:root:Processing index #38 => locus tag PFLU5498
# INFO:root:Querying uvrA aka PFLU5498
# INFO:root:url = https://openknowledgemaps.org/map/658802febc81226c01ecfa65bedea712
# INFO:root:Processing index #39 => locus tag PFLU5499
# INFO:root:Querying bfr2 aka PFLU5499
# INFO:root:url = https://openknowledgemaps.org/map/ac3edcacb0e6697180cbea3b4b233ada
# INFO:root:Processing index #40 => locus tag PFLU5500
# INFO:root:Querying katA aka PFLU5500
# INFO:root:url = https://openknowledgemaps.org/map/25e29136377a509007f88fa6b06a8907
# INFO:root:Processing index #41 => locus tag PFLU5501
# INFO:root:Querying rplQ aka PFLU5501
# INFO:root:url = https://openknowledgemaps.org/map/897a52c661e17632835c9db35a5d59c8
# INFO:root:Processing index #42 => locus tag PFLU5502
# INFO:root:Querying rpoA aka PFLU5502
# INFO:root:url = https://openknowledgemaps.org/map/d07c1737938bfa05f29d2231c0f0671d
# INFO:root:Processing index #43 => locus tag PFLU5503
# INFO:root:Querying rpsD aka PFLU5503
# INFO:root:url = https://openknowledgemaps.org/map/bc5afd929a0431f50ff66b52af33540a
# INFO:root:Processing index #44 => locus tag PFLU5504
# INFO:root:Querying rpsK aka PFLU5504
# INFO:root:url = https://openknowledgemaps.org/map/4262e34b172255923ff43a5ef3c6b585
# INFO:root:Processing index #45 => locus tag PFLU5505
# INFO:root:Querying rpsM aka PFLU5505
# INFO:root:url = https://openknowledgemaps.org/map/014accded9ff1d0759d1b3af92830ee5
# INFO:root:Processing index #46 => locus tag PFLU5506
# INFO:root:Querying rpmJ aka PFLU5506
# INFO:root:url = https://openknowledgemaps.org/map/b03999fb065067f2f8c1819709762264
# INFO:root:Processing index #47 => locus tag PFLU5507
# INFO:root:Querying secY aka PFLU5507
# INFO:root:url = https://openknowledgemaps.org/map/4e3148287a8122ca47ed62aa253f3097
# INFO:root:Processing index #48 => locus tag PFLU5508
# INFO:root:Querying rplO aka PFLU5508
# INFO:root:url = https://openknowledgemaps.org/map/3e6a9cfa230802d2eb44ec83a39b5913
# INFO:root:Processing index #49 => locus tag PFLU5509
# INFO:root:Querying rpmD aka PFLU5509
# INFO:root:url = https://openknowledgemaps.org/map/98169dcd77c58e1d989127f92c8e9083
# INFO:root:Processing index #50 => locus tag PFLU5510
# INFO:root:Querying rpsE aka PFLU5510
# INFO:root:url = https://openknowledgemaps.org/map/b888d8bbe4d0749811b7ca33e8c376f5
# INFO:root:Processing index #51 => locus tag PFLU5511
# INFO:root:Querying rplR aka PFLU5511
# INFO:root:url = https://openknowledgemaps.org/map/35d8adcd76f4ae4b9868874fd08f8785
# INFO:root:Processing index #52 => locus tag PFLU5512
# INFO:root:Querying rplF aka PFLU5512
# INFO:root:url = https://openknowledgemaps.org/map/a54418b5bca6b388f94106d0b7ad4df4
# INFO:root:Processing index #53 => locus tag PFLU5513
# INFO:root:Querying rpsH aka PFLU5513
# INFO:root:url = https://openknowledgemaps.org/map/ed550fd50449a46cb569487de8449484
# INFO:root:Processing index #54 => locus tag PFLU5514
# INFO:root:Querying rpsN aka PFLU5514
# INFO:root:url = https://openknowledgemaps.org/map/8546b9461978c493cfa49a12d35773a0
# INFO:root:Processing index #55 => locus tag PFLU5515
# INFO:root:Querying rplE aka PFLU5515
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #56 => locus tag PFLU5516
# INFO:root:Querying rplX aka PFLU5516
# INFO:root:url = https://openknowledgemaps.org/map/0ae9965dfa13b8779d0b6c5fe3b551cd
# INFO:root:Processing index #57 => locus tag PFLU5517
# INFO:root:Querying rplN aka PFLU5517
# INFO:root:url = https://openknowledgemaps.org/map/3a4041fe9b3fd9c56684aa6508f7336e
# INFO:root:Processing index #58 => locus tag PFLU5518
# INFO:root:Querying rpsQ aka PFLU5518
# INFO:root:url = https://openknowledgemaps.org/map/1cff68c1131d67f14065d88601bf0796
# INFO:root:Processing index #59 => locus tag PFLU5519
# INFO:root:Querying rpmC aka PFLU5519
# INFO:root:url = https://openknowledgemaps.org/map/7591104889c323a81a01fc3dc6cc5a83
# INFO:root:Processing index #60 => locus tag PFLU5520
# INFO:root:Querying rplP aka PFLU5520
# INFO:root:url = https://openknowledgemaps.org/map/699335e4e804ad1208119e99bed58610
# INFO:root:Processing index #61 => locus tag PFLU5521
# INFO:root:Querying rpsC aka PFLU5521
# INFO:root:url = https://openknowledgemaps.org/map/ce2d9337a1b952e634f0f6ae2ce275bb
# INFO:root:Processing index #62 => locus tag PFLU5522
# INFO:root:Querying rplV aka PFLU5522
# INFO:root:url = https://openknowledgemaps.org/map/c775547376f9af130ffe21b0eb24e462
# INFO:root:Processing index #63 => locus tag PFLU5523
# INFO:root:Querying rpsS aka PFLU5523
# INFO:root:url = https://openknowledgemaps.org/map/47ad9da8dff384d6d6079c515911c1cf
# INFO:root:Processing index #64 => locus tag PFLU5524
# INFO:root:Querying rplB aka PFLU5524
# INFO:root:url = https://openknowledgemaps.org/map/d9033a0a442700b78da02c0e6ba8deb3
# INFO:root:Processing index #65 => locus tag PFLU5525
# INFO:root:Querying rplW aka PFLU5525
# INFO:root:url = https://openknowledgemaps.org/map/615876667f15d7a8c977ab049b27681d
# INFO:root:Processing index #66 => locus tag PFLU5526
# INFO:root:Querying rplD aka PFLU5526
# INFO:root:url = https://openknowledgemaps.org/map/9fcfae903b488839cf108a1b2542ae38
# INFO:root:Processing index #67 => locus tag PFLU5527
# INFO:root:Querying rplC aka PFLU5527
# INFO:root:url = https://openknowledgemaps.org/map/38d86387dc6d80d4d51831a26f3a5e4a
# INFO:root:Processing index #68 => locus tag PFLU5528
# INFO:root:Querying rpsJ aka PFLU5528
# INFO:root:url = https://openknowledgemaps.org/map/fed9e185369384923255c91c30d82daf
# INFO:root:Processing index #69 => locus tag PFLU5529
# INFO:root:Querying tufB aka PFLU5529
# INFO:root:url = https://openknowledgemaps.org/map/4296efe5255e4fe4fd56fae3398941b1
# INFO:root:Processing index #70 => locus tag PFLU5530
# INFO:root:Querying fusA aka PFLU5530
# INFO:root:url = https://openknowledgemaps.org/map/525ab0304721a20ba1bdd355b7c3c190
# INFO:root:Processing index #71 => locus tag PFLU5531
# INFO:root:Querying rpsG aka PFLU5531
# INFO:root:url = https://openknowledgemaps.org/map/1b202799fb3bef79263ed605fd3ee8d6
# INFO:root:Processing index #72 => locus tag PFLU5532
# INFO:root:Querying rpsL aka PFLU5532
# INFO:root:url = https://openknowledgemaps.org/map/a0ff00113b0528186b53e57f490c1ad3
# INFO:root:Processing index #73 => locus tag PFLU5533
# INFO:root:Querying rpoC aka PFLU5533
# INFO:root:url = https://openknowledgemaps.org/map/bbb2d7e210470acc8a65604aa586e6fb
# INFO:root:Processing index #74 => locus tag PFLU5534
# INFO:root:Querying rpoB aka PFLU5534
# INFO:root:url = https://openknowledgemaps.org/map/89c0f43e228a0f54c638ebd9ed639a41
# INFO:root:Processing index #75 => locus tag PFLU5535
# INFO:root:Querying rplL aka PFLU5535
# INFO:root:url = https://openknowledgemaps.org/map/ef7e6908a747e4e20d814f485302c1eb
# INFO:root:Processing index #76 => locus tag PFLU5536
# INFO:root:Querying rplJ aka PFLU5536
# INFO:root:url = https://openknowledgemaps.org/map/5f21a7378990c977b7beac6e6ebc6530
# INFO:root:Processing index #77 => locus tag PFLU5537
# INFO:root:Querying rplA aka PFLU5537
# INFO:root:url = https://openknowledgemaps.org/map/fe908995687d7d2305991fa4a5c0a48a
# INFO:root:Processing index #78 => locus tag PFLU5538
# INFO:root:Querying rplK aka PFLU5538
# INFO:root:url = https://openknowledgemaps.org/map/d06fc265d078d0eba141915bf3f3ddce
# INFO:root:Processing index #79 => locus tag PFLU5539
# INFO:root:Querying nusG aka PFLU5539
# INFO:root:url = https://openknowledgemaps.org/map/569aa5bd36cf73268979ddafde8effc1
# INFO:root:Processing index #80 => locus tag PFLU5540
# INFO:root:Querying secE aka PFLU5540
# INFO:root:url = https://openknowledgemaps.org/map/7554e554ef5263e291b6e1b791283da9
# INFO:root:Processing index #81 => locus tag PFLU5543
# INFO:root:Querying birA aka PFLU5543
# INFO:root:url = https://openknowledgemaps.org/map/5da19f8dcbb7515f58cd8336be53bec9
# INFO:root:Processing index #82 => locus tag PFLU5544
# INFO:root:Querying tyrZ aka PFLU5544
# INFO:root:url = https://openknowledgemaps.org/map/21772db68984cdd451e3ea6c7bb68b73
# INFO:root:Processing index #83 => locus tag PFLU5546
# INFO:root:Querying anmK aka PFLU5546
# INFO:root:url = https://openknowledgemaps.org/map/6a2e47a0b1f8d3d29f5e9f12f5879223
# INFO:root:Processing index #84 => locus tag PFLU5548
# INFO:root:Querying argC aka PFLU5548
# INFO:root:url = https://openknowledgemaps.org/map/0c150c747c1978788812142bf8696bdc
# INFO:root:Processing index #85 => locus tag PFLU5556
# INFO:root:Querying crp aka PFLU5556
# INFO:root:url = https://openknowledgemaps.org/map/897891853037c4412fb537e69f4eda5b
# INFO:root:Processing index #86 => locus tag PFLU5558
# INFO:root:Querying trpC aka PFLU5558
# INFO:root:url = https://openknowledgemaps.org/map/708940ab925b7b78400d6c0967545517
# INFO:root:Processing index #87 => locus tag PFLU5559
# INFO:root:Querying trpD aka PFLU5559
# INFO:root:url = https://openknowledgemaps.org/map/8fb01171a96375e59902ab6daccdad56
# INFO:root:Processing index #88 => locus tag PFLU5560
# INFO:root:Querying trpG aka PFLU5560
# INFO:root:url = https://openknowledgemaps.org/map/60814bf5e76004110fb54194335390c1
# INFO:root:Processing index #89 => locus tag PFLU5561
# INFO:root:Querying trpE aka PFLU5561
# INFO:root:url = https://openknowledgemaps.org/map/22b64520684bbbe3bce585c086452c2c
# INFO:root:Processing index #90 => locus tag PFLU5563
# INFO:root:Querying rpe aka PFLU5563
# INFO:root:url = https://openknowledgemaps.org/map/159e3c80ee1807404e457d7f0ac184a5
# INFO:root:Processing index #91 => locus tag PFLU5577
# INFO:root:Querying pdxA aka PFLU5577
# INFO:root:url = https://openknowledgemaps.org/map/11a5e2ed0792c51fa4682338e70ff7c0
# INFO:root:Processing index #92 => locus tag PFLU5578
# INFO:root:Querying ksgA aka PFLU5578
# INFO:root:url = https://openknowledgemaps.org/map/74f053240e671fbd93cdf5713ba5ad89
# INFO:root:Processing index #93 => locus tag PFLU5579
# INFO:root:Querying apaG aka PFLU5579
# INFO:root:url = https://openknowledgemaps.org/map/f820f11d928fc320720b13df4721552f
# INFO:root:Processing index #94 => locus tag PFLU5580
# INFO:root:Querying apaH aka PFLU5580
# INFO:root:url = https://openknowledgemaps.org/map/20f0367d468ef959938e6f53984080c7
# INFO:root:Processing index #95 => locus tag PFLU5581
# INFO:root:Querying glpE aka PFLU5581
# INFO:root:url = https://openknowledgemaps.org/map/2125c21e1a1dc38b630cf10002f98539
# INFO:root:Processing index #96 => locus tag PFLU5585
# INFO:root:Querying cca aka PFLU5585
# INFO:root:url = https://openknowledgemaps.org/map/54e1549421ecd1f31924efee994983d0
# INFO:root:Processing index #97 => locus tag PFLU5587
# INFO:root:Querying folB aka PFLU5587
# INFO:root:url = https://openknowledgemaps.org/map/58a0b41d326328073dc308baf07988ff
# INFO:root:Processing index #98 => locus tag PFLU5589
# INFO:root:Querying gcp aka PFLU5589
# INFO:root:url = https://openknowledgemaps.org/map/f1d8a676e6a7cc819a4231fd269a52f3
# INFO:root:Processing index #99 => locus tag PFLU5591
# INFO:root:Querying dnaG aka PFLU5591
# INFO:root:url = https://openknowledgemaps.org/map/9969f9ad45d3eb173b00b1a324cc3808
# INFO:root:Processing index #100 => locus tag PFLU5592
# INFO:root:Querying rpoD aka PFLU5592
# INFO:root:url = https://openknowledgemaps.org/map/6d41fa8d721e6d82c970415012a1240f
# INFO:root:Processing index #101 => locus tag PFLU5598
# INFO:root:Querying pqqA aka PFLU5598
# INFO:root:url = https://openknowledgemaps.org/map/1435a2d4b32971b17e8af1542911bedc
# INFO:root:Processing index #102 => locus tag PFLU5599
# INFO:root:Querying pqqB aka PFLU5599
# INFO:root:url = https://openknowledgemaps.org/map/cb1424f8a095d714dfe506311f9ce9b1
# INFO:root:Processing index #103 => locus tag PFLU5600
# INFO:root:Querying pqqC aka PFLU5600
# INFO:root:url = https://openknowledgemaps.org/map/cbd4246e15413ce2fef97a5213ae4fa3
# INFO:root:Processing index #104 => locus tag PFLU5601
# INFO:root:Querying pqqD aka PFLU5601
# INFO:root:url = https://openknowledgemaps.org/map/0ec503d998bcad99ea6e8755b9a75932
# INFO:root:Processing index #105 => locus tag PFLU5602
# INFO:root:Querying pqqE aka PFLU5602
# INFO:root:url = https://openknowledgemaps.org/map/a35dc9de0d0cddf0235f3429e988397e
# INFO:root:Processing index #106 => locus tag PFLU5611
# INFO:root:Querying bioD aka PFLU5611
# INFO:root:url = https://openknowledgemaps.org/map/d78d27b252e3c110bbe46c8de0f174dd
# INFO:root:Processing index #107 => locus tag PFLU5614
# INFO:root:Querying bioF aka PFLU5614
# INFO:root:url = https://openknowledgemaps.org/map/092fd2427c3923d4e0e32f62b57e040a
# INFO:root:Processing index #108 => locus tag PFLU5615
# INFO:root:Querying bioB aka PFLU5615
# INFO:root:url = https://openknowledgemaps.org/map/30304b3f25fb147a9305a0983049d8e7
# INFO:root:Processing index #109 => locus tag PFLU5623
# INFO:root:Querying glcB aka PFLU5623
# INFO:root:url = https://openknowledgemaps.org/map/30c2dfd575fc514fbb860d64a68a7871
# INFO:root:Processing index #110 => locus tag PFLU5640
# INFO:root:Querying creC aka PFLU5640
# INFO:root:url = https://openknowledgemaps.org/map/e502e53be1d30eb24d0af96e7c903c7f
# INFO:root:Processing index #111 => locus tag PFLU5641
# INFO:root:Querying creB aka PFLU5641
# INFO:root:url = https://openknowledgemaps.org/map/7404954ef6deecbcf91eefefb89027a2
# INFO:root:Processing index #112 => locus tag PFLU5646
# INFO:root:Querying fdhA aka PFLU5646
# INFO:root:url = https://openknowledgemaps.org/map/ed0ff541810ee1e794000ab1328ff09f
# INFO:root:Processing index #113 => locus tag PFLU5647
# INFO:root:Querying purU aka PFLU5647
# INFO:root:url = https://openknowledgemaps.org/map/73424c79d7e7bc60fbea1b909631923c
# INFO:root:Processing index #114 => locus tag PFLU5649
# INFO:root:Querying soxA aka PFLU5649
# INFO:root:url = https://openknowledgemaps.org/map/75a1f86a3c7a385a0036886eaf2b3970
# INFO:root:Processing index #115 => locus tag PFLU5650
# INFO:root:Querying soxD aka PFLU5650
# INFO:root:url = https://openknowledgemaps.org/map/48307aae3c045e1cc5104aacedd0a40c
# INFO:root:Processing index #116 => locus tag PFLU5651
# INFO:root:Querying soxB aka PFLU5651
# INFO:root:url = https://openknowledgemaps.org/map/e1cd95c656594c7e344309648b4377b3
# INFO:root:Processing index #117 => locus tag PFLU5652
# INFO:root:Querying glyA aka PFLU5652
# INFO:root:url = https://openknowledgemaps.org/map/47bff8bc79e7958b3b85c8b3e801b08b
# INFO:root:Processing index #118 => locus tag PFLU5654
# INFO:root:Querying ltaE aka PFLU5654
# INFO:root:url = https://openknowledgemaps.org/map/d57d4fd8041bf4617226ddbbd7c320fc
# INFO:root:Processing index #119 => locus tag PFLU5679
# INFO:root:Querying sdaA aka PFLU5679
# INFO:root:url = https://openknowledgemaps.org/map/8a7e39ee3689c29e5f6cb7ea9c56e638
# INFO:root:Processing index #120 => locus tag PFLU5683
# INFO:root:Querying betT aka PFLU5683
# INFO:root:url = https://openknowledgemaps.org/map/b0ce40521a37c9c09627b9facdc6f74b
# INFO:root:Processing index #121 => locus tag PFLU5684
# INFO:root:Querying betI aka PFLU5684
# INFO:root:url = https://openknowledgemaps.org/map/f43a679f5786e24dec7b162577bf3333
# INFO:root:Processing index #122 => locus tag PFLU5685
# INFO:root:Querying betB aka PFLU5685
# INFO:root:url = https://openknowledgemaps.org/map/3436989868307ff6cb6fcb80b932b6e9
# INFO:root:Processing index #123 => locus tag PFLU5686
# INFO:root:Querying betA aka PFLU5686
# INFO:root:url = https://openknowledgemaps.org/map/437ba1d8c7567e2b42ff3ec0d491f3cc
# INFO:root:Processing index #124 => locus tag PFLU5689
# INFO:root:Querying rhlA aka PFLU5689
# INFO:root:url = https://openknowledgemaps.org/map/1a9c9c8cb0d0851787d375fe4e46d9f8
# INFO:root:Processing index #125 => locus tag PFLU5691
# INFO:root:Querying dbpA aka PFLU5691
# INFO:root:url = https://openknowledgemaps.org/map/77c2d667cf46558a346976889a57ce79
# INFO:root:Processing index #126 => locus tag PFLU5701
# INFO:root:Querying fbA aka PFLU5701
# INFO:root:url = https://openknowledgemaps.org/map/b3d33adf93327cb1da003f5899915f1c
# INFO:root:Processing index #127 => locus tag PFLU5705
# INFO:root:Querying pgk aka PFLU5705
# INFO:root:url = https://openknowledgemaps.org/map/35a925ed6fda690210e89170c73bd473
# INFO:root:Processing index #128 => locus tag PFLU5706
# INFO:root:Querying epd aka PFLU5706
# INFO:root:url = https://openknowledgemaps.org/map/def421964fdaa8f82dc7197ac1c60883
# INFO:root:Processing index #129 => locus tag PFLU5707
# INFO:root:Querying tktA aka PFLU5707
# INFO:root:url = https://openknowledgemaps.org/map/008ed5102ccdf7d43f0d6967c9c83589
# INFO:root:Processing index #130 => locus tag PFLU5709
# INFO:root:Querying metK aka PFLU5709
# INFO:root:url = https://openknowledgemaps.org/map/1cb0d44a7a07e4b70ba427505331a67d
# INFO:root:Processing index #131 => locus tag PFLU5711
# INFO:root:Querying ligB aka PFLU5711
# INFO:root:url = https://openknowledgemaps.org/map/e444d1c5940f0d9a97fbc9a65f9d41e6
# INFO:root:Processing index #132 => locus tag PFLU5720
# INFO:root:Querying sahA aka PFLU5720
# INFO:root:url = https://openknowledgemaps.org/map/cac58c42b75685cd408aae66a65363eb
# INFO:root:Processing index #133 => locus tag PFLU5721
# INFO:root:Querying metF aka PFLU5721
# INFO:root:url = https://openknowledgemaps.org/map/f6edc6d1eaeada636b5d6b6f4f425be7
# INFO:root:Processing index #134 => locus tag PFLU5724
# INFO:root:Querying rhlE1 aka PFLU5724
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #135 => locus tag PFLU5726
# INFO:root:Querying cybB aka PFLU5726
# INFO:root:url = https://openknowledgemaps.org/map/b979663987cefde6a11df6e1e33daa96
# INFO:root:Processing index #136 => locus tag PFLU5727
# INFO:root:Querying bioA aka PFLU5727
# INFO:root:url = https://openknowledgemaps.org/map/221e0a2a1f7fdb62ccd2ba97514a1aee
# INFO:root:Processing index #137 => locus tag PFLU5749
# INFO:root:Querying pilJ aka PFLU5749
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #138 => locus tag PFLU5750
# INFO:root:Querying pilI aka PFLU5750
# INFO:root:url = https://openknowledgemaps.org/map/2e66fca4bc0455910221e087cbc20e5f
# INFO:root:Processing index #139 => locus tag PFLU5751
# INFO:root:Querying pilH aka PFLU5751
# INFO:root:url = https://openknowledgemaps.org/map/71bf7b873a10277592896eebcafd583a
# INFO:root:Processing index #140 => locus tag PFLU5752
# INFO:root:Querying pilG aka PFLU5752
# INFO:root:url = https://openknowledgemaps.org/map/137dbfc6b0de405dbb253398eec02f55
# INFO:root:Processing index #141 => locus tag PFLU5753
# INFO:root:Querying gshB aka PFLU5753
# INFO:root:url = https://openknowledgemaps.org/map/53b967ac7a729d963df3c048674d1b43
# INFO:root:Processing index #142 => locus tag PFLU5757
# INFO:root:Querying pyrR aka PFLU5757
# INFO:root:url = https://openknowledgemaps.org/map/1e6be5f62b41d555fbfdbda2c5cda941
# INFO:root:Processing index #143 => locus tag PFLU5758
# INFO:root:Querying pyrB aka PFLU5758
# INFO:root:url = https://openknowledgemaps.org/map/644f9b5ad55c9c833f21547c0fb19379
# INFO:root:Processing index #144 => locus tag PFLU5759
# INFO:root:Querying pyrC aka PFLU5759
# INFO:root:url = https://openknowledgemaps.org/map/ef0cdc3bf30a11565979470a75b76c22
# INFO:root:Processing index #145 => locus tag PFLU5762
# INFO:root:Querying pilT aka PFLU5762
# INFO:root:url = https://openknowledgemaps.org/map/7547d0c566208b3e8025d86ce378babd
# INFO:root:Processing index #146 => locus tag PFLU5766
# INFO:root:Querying metX aka PFLU5766
# INFO:root:url = https://openknowledgemaps.org/map/ed81fd0d9aadfd40130763640f90e9e3
# INFO:root:Processing index #147 => locus tag PFLU5772
# INFO:root:Querying trmB aka PFLU5772
# INFO:root:url = https://openknowledgemaps.org/map/6dab21429d5673c735c37a9725554e5b
# INFO:root:Processing index #148 => locus tag PFLU5773
# INFO:root:Querying thiG aka PFLU5773
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #149 => locus tag PFLU5776
# INFO:root:Querying mtgA aka PFLU5776
# INFO:root:url = https://openknowledgemaps.org/map/212e1056ed9cd1583b4a3a13ac82ce80
# INFO:root:Processing index #150 => locus tag PFLU5777
# INFO:root:Querying rpoH aka PFLU5777
# INFO:root:url = https://openknowledgemaps.org/map/9b17f291ca3470a29e461ef2d8f04f89
# INFO:root:Processing index #151 => locus tag PFLU5779
# INFO:root:Querying ftsE aka PFLU5779
# INFO:root:url = https://openknowledgemaps.org/map/7ab393928b429f5d52af40d58786e10f
# INFO:root:Processing index #152 => locus tag PFLU5780
# INFO:root:Querying ftsY aka PFLU5780
# INFO:root:url = https://openknowledgemaps.org/map/78b55c6c623472625153f9a2401d087b
# INFO:root:Processing index #153 => locus tag PFLU5791
# INFO:root:Querying coaD aka PFLU5791
# INFO:root:url = https://openknowledgemaps.org/map/541db3154649d2797295264eca6585b2
# INFO:root:Processing index #154 => locus tag PFLU5792
# INFO:root:Querying fdx aka PFLU5792
# INFO:root:url = https://openknowledgemaps.org/map/6b1d15bf37b34cef3ecaf2399bc02d79
# INFO:root:Processing index #155 => locus tag PFLU5793
# INFO:root:Querying mutM aka PFLU5793
# INFO:root:url = https://openknowledgemaps.org/map/13b9eaf876c3d574c301c11321dd8892
# INFO:root:Processing index #156 => locus tag PFLU5797
# INFO:root:Querying ilvD aka PFLU5797
# INFO:root:url = https://openknowledgemaps.org/map/7302ce7d0cdd6517b8738fc91e977e31
# INFO:root:Processing index #157 => locus tag PFLU5803
# INFO:root:Querying folA aka PFLU5803
# INFO:root:url = https://openknowledgemaps.org/map/6fed14ec5c1f8d59ddc8ea39944c1b03
# INFO:root:Processing index #158 => locus tag PFLU5815
# INFO:root:Querying thyA aka PFLU5815
# INFO:root:url = https://openknowledgemaps.org/map/b8f3a77eeb860640f8697a8c09fb1422
# INFO:root:Processing index #159 => locus tag PFLU5816
# INFO:root:Querying lgt aka PFLU5816
# INFO:root:url = https://openknowledgemaps.org/map/1d8d947243eb215e5083ada586c4ceec
# INFO:root:Processing index #160 => locus tag PFLU5819
# INFO:root:Querying ptsP aka PFLU5819
# INFO:root:url = https://openknowledgemaps.org/map/2226262fc7e5e6920e849594e91d9cc3
# INFO:root:Processing index #161 => locus tag PFLU5820
# INFO:root:Querying nudH aka PFLU5820
# INFO:root:url = https://openknowledgemaps.org/map/a47e8adc11ecd55ae34a87e32d6a497e
# INFO:root:Processing index #162 => locus tag PFLU5823
# INFO:root:Querying ilvA aka PFLU5823
# INFO:root:url = https://openknowledgemaps.org/map/89f63e45715d8ac52edaf729611c7367
# INFO:root:Processing index #163 => locus tag PFLU5824
# INFO:root:Querying rpiA aka PFLU5824
# INFO:root:url = https://openknowledgemaps.org/map/0a3d442b70097d8be60e99f56285df4d
# INFO:root:Processing index #164 => locus tag PFLU5829
# INFO:root:Querying serA aka PFLU5829
# INFO:root:url = https://openknowledgemaps.org/map/60efd68a82dafd23f23130323df8b878
# INFO:root:Processing index #165 => locus tag PFLU5841
# INFO:root:Querying potI aka PFLU5841
# INFO:root:url = https://openknowledgemaps.org/map/756a95f5b45abb63f799e2c26f37a401
# INFO:root:Processing index #166 => locus tag PFLU5842
# INFO:root:Querying potH aka PFLU5842
# INFO:root:url = https://openknowledgemaps.org/map/2b33f49a999e05f74a55bea36ea1478e
# INFO:root:Processing index #167 => locus tag PFLU5843
# INFO:root:Querying potG aka PFLU5843
# INFO:root:url = https://openknowledgemaps.org/map/fa29bdb011f2ac4f9cd5ab8d9b1447b7
# INFO:root:Processing index #168 => locus tag PFLU5844
# INFO:root:Querying potF2 aka PFLU5844
# INFO:root:url = https://openknowledgemaps.org/map/e59b261d7d07d10f5a190fd6dc8f953f
# INFO:root:Processing index #169 => locus tag PFLU5845
# INFO:root:Querying potF1 aka PFLU5845
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #170 => locus tag PFLU5854
# INFO:root:Querying ssuB aka PFLU5854
# INFO:root:url = https://openknowledgemaps.org/map/6ee28b816c1f725804b641f72544a78e
# INFO:root:Processing index #171 => locus tag PFLU5855
# INFO:root:Querying ssuC aka PFLU5855
# INFO:root:url = https://openknowledgemaps.org/map/5c81d0a820633b940d33b855d2a9dac8
# INFO:root:Processing index #172 => locus tag PFLU5856
# INFO:root:Querying ssuD aka PFLU5856
# INFO:root:url = https://openknowledgemaps.org/map/9df783bc42b210174cb6e55958825cf1
# INFO:root:Processing index #173 => locus tag PFLU5857
# INFO:root:Querying ssuA aka PFLU5857
# INFO:root:url = https://openknowledgemaps.org/map/8cc9f64c9fdb79a6939bcc3260b838c1
# INFO:root:Processing index #174 => locus tag PFLU5858
# INFO:root:Querying ssuE aka PFLU5858
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #175 => locus tag PFLU5862
# INFO:root:Querying argA aka PFLU5862
# INFO:root:url = https://openknowledgemaps.org/map/10150871baebcb7eb9343451b5162363
# INFO:root:Processing index #176 => locus tag PFLU5863
# INFO:root:Querying argE aka PFLU5863
# INFO:root:url = https://openknowledgemaps.org/map/d7cdae65aa12cd6e96a827274be7ce64
# INFO:root:Processing index #177 => locus tag PFLU5873
# INFO:root:Querying gcvH aka PFLU5873
# INFO:root:url = https://openknowledgemaps.org/map/5467909ab53795b6b5c77252c3fe7766
# INFO:root:Processing index #178 => locus tag PFLU5874
# INFO:root:Querying gcvT aka PFLU5874
# INFO:root:url = https://openknowledgemaps.org/map/f8551337324f0e669b976ddcae85e486
# INFO:root:Processing index #179 => locus tag PFLU5880
# INFO:root:Querying pepP aka PFLU5880
# INFO:root:url = https://openknowledgemaps.org/map/6a601aaa39b0a53e0e0252b70451cc81
# INFO:root:Processing index #180 => locus tag PFLU5893
# INFO:root:Querying glpT aka PFLU5893
# INFO:root:url = https://openknowledgemaps.org/map/d15e2fe89c751c5f7fe15b90da6f7826
# INFO:root:Processing index #181 => locus tag PFLU5898
# INFO:root:Querying ubiD aka PFLU5898
# INFO:root:url = https://openknowledgemaps.org/map/b38435cb9b117b031989d0f42c46f136
# INFO:root:Processing index #182 => locus tag PFLU5900
# INFO:root:Querying rho aka PFLU5900
# INFO:root:url = https://openknowledgemaps.org/map/64e6e32d433972e0dfa0dd15d7bc4ff5
# INFO:root:Processing index #183 => locus tag PFLU5901
# INFO:root:Querying trxA aka PFLU5901
# INFO:root:url = https://openknowledgemaps.org/map/2da5039c18a7dcb7c7bb8aa048f4e056
# INFO:root:Processing index #184 => locus tag PFLU5911
# INFO:root:Querying ppx aka PFLU5911
# INFO:root:url = https://openknowledgemaps.org/map/ad4e9eefe81b7f9738d95990c379d13b
# INFO:root:Processing index #185 => locus tag PFLU5913
# INFO:root:Querying hemB aka PFLU5913
# INFO:root:url = https://openknowledgemaps.org/map/56808053040f2ec5de4afc9f47e3c1ba
# INFO:root:Processing index #186 => locus tag PFLU5916
# INFO:root:Querying elbB aka PFLU5916
# INFO:root:url = https://openknowledgemaps.org/map/760736568433083e5a495d9a6864e718
# INFO:root:Processing index #187 => locus tag PFLU5927
# INFO:root:Querying algP1 aka PFLU5927
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #188 => locus tag PFLU5929
# INFO:root:Querying algQ aka PFLU5929
# INFO:root:url = https://openknowledgemaps.org/map/ec8dbe0a595f4d3950556283b0f86a82
# INFO:root:Processing index #189 => locus tag PFLU5933
# INFO:root:Querying hemD aka PFLU5933
# INFO:root:url = https://openknowledgemaps.org/map/4f5e1cca83f5c4626da43e8f0ef9f0b0
# INFO:root:Processing index #190 => locus tag PFLU5934
# INFO:root:Querying hemC aka PFLU5934
# INFO:root:url = https://openknowledgemaps.org/map/b7302373b8e4bd3146a653771ddbdf17
# INFO:root:Processing index #191 => locus tag PFLU5935
# INFO:root:Querying algR aka PFLU5935
# INFO:root:url = https://openknowledgemaps.org/map/3e2e2a3ce563cbbdba87f26223ba571b
# INFO:root:Processing index #192 => locus tag PFLU5936
# INFO:root:Querying argH aka PFLU5936
# INFO:root:url = https://openknowledgemaps.org/map/a3bc27d9dcd62f101f5f713a85b29daa
# INFO:root:Processing index #193 => locus tag PFLU5940
# INFO:root:Querying cyaA aka PFLU5940
# INFO:root:url = https://openknowledgemaps.org/map/2438c577f811c40ea4db5200886d5f40
# INFO:root:Processing index #194 => locus tag PFLU5941
# INFO:root:Querying rnk aka PFLU5941
# INFO:root:url = https://openknowledgemaps.org/map/26aac28a5c0a2e93136530077340a1f1
# INFO:root:Processing index #195 => locus tag PFLU5943
# INFO:root:Querying cyaY aka PFLU5943
# INFO:root:url = https://openknowledgemaps.org/map/8301e48c6deb9f66077730731c1ce581
# INFO:root:Processing index #196 => locus tag PFLU5944
# INFO:root:Querying lppL aka PFLU5944
# INFO:root:url = https://openknowledgemaps.org/map/9fffe8edbd803d3f56209ca601dbe3a0
# INFO:root:Processing index #197 => locus tag PFLU5945
# INFO:root:Querying lysA aka PFLU5945
# INFO:root:url = https://openknowledgemaps.org/map/6af5caf0987267f4d94233c94b5ec519
# INFO:root:Processing index #198 => locus tag PFLU5946
# INFO:root:Querying dapF aka PFLU5946
# INFO:root:url = https://openknowledgemaps.org/map/b849838dcacee5d8bdaab546655761c4
# INFO:root:Processing index #199 => locus tag PFLU5948
# INFO:root:Querying xerC aka PFLU5948
# INFO:root:url = https://openknowledgemaps.org/map/ac73a256222951a3ca0744d13d2a0902
# INFO:root:Processing index #200 => locus tag PFLU5953
# INFO:root:Querying glnK aka PFLU5953
# INFO:root:url = https://openknowledgemaps.org/map/e66400d195c3c71a5caf5a6a0094bc3d
# INFO:root:Processing index #201 => locus tag PFLU5956
# INFO:root:Querying comM aka PFLU5956
# INFO:root:url = https://openknowledgemaps.org/map/f65b6f1102ccfa036239dc6620ea9cb0
# INFO:root:Processing index #202 => locus tag PFLU5961
# INFO:root:Querying rep aka PFLU5961
# INFO:root:url = https://openknowledgemaps.org/map/8fb30ad522282a7dfaa4d13aebd9e1f0
# INFO:root:Processing index #203 => locus tag PFLU5962
# INFO:root:Querying xpt aka PFLU5962
# INFO:root:url = https://openknowledgemaps.org/map/2d966c11375447128ef30ae409358e8f
# INFO:root:Processing index #204 => locus tag PFLU5966
# INFO:root:Querying dadX aka PFLU5966
# INFO:root:url = https://openknowledgemaps.org/map/6e8650611685785955ba0516c5328295
# INFO:root:Processing index #205 => locus tag PFLU5968
# INFO:root:Querying dadA aka PFLU5968
# INFO:root:url = https://openknowledgemaps.org/map/2b2dd9a64d5ffc6df5b94f56e1e64538
# INFO:root:Processing index #206 => locus tag PFLU5969
# INFO:root:Querying lrp aka PFLU5969
# INFO:root:url = https://openknowledgemaps.org/map/af8e1b2821130fc41b049fa5844269a3
# INFO:root:Processing index #207 => locus tag PFLU5976
# INFO:root:Querying aldH aka PFLU5976
# INFO:root:url = https://openknowledgemaps.org/map/3c91dd8d02c6c8a894bc66d3d0ea0cec
# INFO:root:Processing index #208 => locus tag PFLU5979
# INFO:root:Querying rpmG aka PFLU5979
# INFO:root:url = https://openknowledgemaps.org/map/39bc0c65d11e2575a46eb18087e35eba
# INFO:root:Processing index #209 => locus tag PFLU5980
# INFO:root:Querying rpmB aka PFLU5980
# INFO:root:url = https://openknowledgemaps.org/map/de921cb3785dee51906ecd51271178d0
# INFO:root:Processing index #210 => locus tag PFLU5982
# INFO:root:Querying radC aka PFLU5982
# INFO:root:url = https://openknowledgemaps.org/map/64fc2475a560daf20b68944d69fbe71e
# INFO:root:Processing index #211 => locus tag PFLU5983
# INFO:root:Querying coaBC aka PFLU5983
# INFO:root:url = https://openknowledgemaps.org/map/2e47b4d8a8b15177ad0d57cc1b241102
# INFO:root:Processing index #212 => locus tag PFLU5984
# INFO:root:Querying dut aka PFLU5984
# INFO:root:url = https://openknowledgemaps.org/map/3a910bed009b32d7d5c22dc508166da5
# INFO:root:Processing index #213 => locus tag PFLU5987
# INFO:root:Querying argB aka PFLU5987
# INFO:root:url = https://openknowledgemaps.org/map/da3c9cce035ae8e80a359c11b8effe13
# INFO:root:Processing index #214 => locus tag PFLU5988
# INFO:root:Querying pyrE aka PFLU5988
# INFO:root:url = https://openknowledgemaps.org/map/02ff1caac8d8e4b3dba61cbb926a95c7
# INFO:root:Processing index #215 => locus tag PFLU5991
# INFO:root:Querying rph aka PFLU5991
# INFO:root:url = https://openknowledgemaps.org/map/a8659ff4da240fee586e2863ef5c67e2
# INFO:root:Processing index #216 => locus tag PFLU5993
# INFO:root:Querying gmk aka PFLU5993
# INFO:root:url = https://openknowledgemaps.org/map/7cced29e4893f7e3b24057cdd6977861
# INFO:root:Processing index #217 => locus tag PFLU5994
# INFO:root:Querying rpoZ aka PFLU5994
# INFO:root:url = https://openknowledgemaps.org/map/4cb8843df4f8f51dda008396fe8371f4
# INFO:root:Processing index #218 => locus tag PFLU5995
# INFO:root:Querying spoT aka PFLU5995
# INFO:root:url = https://openknowledgemaps.org/map/3174cf5e1f735ac7976faebcd8645667
# INFO:root:Processing index #219 => locus tag PFLU5999
# INFO:root:Querying exbB aka PFLU5999
# INFO:root:url = https://openknowledgemaps.org/map/3b8a8e16cac137b97195a6886d5b7ebe
# INFO:root:Processing index #220 => locus tag PFLU6000
# INFO:root:Querying exbD aka PFLU6000
# INFO:root:url = https://openknowledgemaps.org/map/518ae45c8f4cdf1ff027f238bc881f93
# INFO:root:Processing index #221 => locus tag PFLU6003
# INFO:root:Querying recG aka PFLU6003
# INFO:root:url = https://openknowledgemaps.org/map/67936038243a063931b6fb136c17dd8f
# INFO:root:Processing index #222 => locus tag PFLU6025
# INFO:root:Querying clpB2 aka PFLU6025
# INFO:root:url = https://openknowledgemaps.org/map/4c36ee28a24f19aebc124b7dea2a7352
# INFO:root:Processing index #223 => locus tag PFLU6032
# INFO:root:Querying hupA aka PFLU6032
# INFO:root:url = https://openknowledgemaps.org/map/b2404220bf1a005d01fab4b70323c270
# INFO:root:Processing index #224 => locus tag PFLU6036
# INFO:root:Querying ubiA aka PFLU6036
# INFO:root:url = https://openknowledgemaps.org/map/6164188b5e6a56c95beb58bef0544bab
# INFO:root:Processing index #225 => locus tag PFLU6039
# INFO:root:Querying phoB aka PFLU6039
# INFO:root:url = https://openknowledgemaps.org/map/e358457b8ce53bbea97341c103f4a1d2
# INFO:root:Processing index #226 => locus tag PFLU6040
# INFO:root:Querying phoR aka PFLU6040
# INFO:root:url = https://openknowledgemaps.org/map/ff964c61a9ded2f12853b5af92229627
# INFO:root:Processing index #227 => locus tag PFLU6044
# INFO:root:Querying phoU aka PFLU6044
# INFO:root:url = https://openknowledgemaps.org/map/2d60438761714d3262c28e547900a31b
# INFO:root:Processing index #228 => locus tag PFLU6045
# INFO:root:Querying pstB aka PFLU6045
# INFO:root:url = https://openknowledgemaps.org/map/7eb5dfec5f9b8ae122bf934425afd064
# INFO:root:Processing index #229 => locus tag PFLU6054
# INFO:root:Querying purK aka PFLU6054
# INFO:root:url = https://openknowledgemaps.org/map/d38cab6daae134533b9e010c87a72c65
# INFO:root:Processing index #230 => locus tag PFLU6055
# INFO:root:Querying purE aka PFLU6055
# INFO:root:url = https://openknowledgemaps.org/map/b9c9bb4d9dcdf3c7f161102c5d5bb775
# INFO:root:Processing index #231 => locus tag PFLU6057
# INFO:root:Querying aspA aka PFLU6057
# INFO:root:url = https://openknowledgemaps.org/map/8f8ccb75d7506bbeb2bc818f0948794c
# INFO:root:Processing index #232 => locus tag PFLU6061
# INFO:root:Querying aphA aka PFLU6061
# INFO:root:url = https://openknowledgemaps.org/map/888ca9c1a00d040bcba73dee85c59bea
# INFO:root:Processing index #233 => locus tag PFLU6062
# INFO:root:Querying potF aka PFLU6062
# INFO:root:url = https://openknowledgemaps.org/map/ac1bbc03c21729bdec7958c899be31d9
# INFO:root:Processing index #234 => locus tag PFLU6070
# INFO:root:Querying oadA aka PFLU6070
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #235 => locus tag PFLU6071
# INFO:root:Querying accC aka PFLU6071
# INFO:root:url = https://openknowledgemaps.org/map/db413627d6b987e3bb869b9ec420e986
# INFO:root:Processing index #236 => locus tag PFLU6075
# INFO:root:Querying uvrD aka PFLU6075
# INFO:root:url = https://openknowledgemaps.org/map/9b5a65185df8609bf9014c50affb7a6d
# INFO:root:Processing index #237 => locus tag PFLU6081
# INFO:root:Querying pdxY aka PFLU6081
# INFO:root:url = https://openknowledgemaps.org/map/055563c3c1f3e876a3e323eb0c874a7f
# INFO:root:Processing index #238 => locus tag PFLU6092
# INFO:root:Querying hisI aka PFLU6092
# INFO:root:url = https://openknowledgemaps.org/map/6ca4c34ad204897e79698d9087a4f946
# INFO:root:Processing index #239 => locus tag PFLU6096
# INFO:root:Querying cls aka PFLU6096
# INFO:root:url = https://openknowledgemaps.org/map/fb1ad081157b2ebf1dcd7915293d2fd7
# INFO:root:Processing index #240 => locus tag PFLU6114
# INFO:root:Querying glmS aka PFLU6114
# INFO:root:url = https://openknowledgemaps.org/map/123491bd503863a43396e03f7d83bafd
# INFO:root:Processing index #241 => locus tag PFLU6115
# INFO:root:Querying srlR aka PFLU6115
# INFO:root:url = https://openknowledgemaps.org/map/77268b70cd32e8dbedb000214dce7872
# INFO:root:Processing index #242 => locus tag PFLU6116
# INFO:root:Querying glmU aka PFLU6116
# INFO:root:url = https://openknowledgemaps.org/map/b14aba45f7f6fca459e4fe9ff7e0a1b5
# INFO:root:Processing index #243 => locus tag PFLU6117
# INFO:root:Querying atpC aka PFLU6117
# INFO:root:url = https://openknowledgemaps.org/map/8904450bb84ca828ec89da7dac210b22
# INFO:root:Processing index #244 => locus tag PFLU6118
# INFO:root:Querying atpD aka PFLU6118
# INFO:root:url = https://openknowledgemaps.org/map/455a78f9511d093a0e78846204aef699
# INFO:root:Processing index #245 => locus tag PFLU6119
# INFO:root:Querying atpG aka PFLU6119
# INFO:root:url = https://openknowledgemaps.org/map/087e1f1ca56acc15d6ae932d297dbea2
# INFO:root:Processing index #246 => locus tag PFLU6120
# INFO:root:Querying atpA aka PFLU6120
# INFO:root:url = https://openknowledgemaps.org/map/2a68f88d4f34643cfcae7a958610d11d
# INFO:root:Processing index #247 => locus tag PFLU6121
# INFO:root:Querying atpH aka PFLU6121
# INFO:root:url = https://openknowledgemaps.org/map/967c314b00aa9f6dba26ab30f4fc0873
# INFO:root:Processing index #248 => locus tag PFLU6122
# INFO:root:Querying atpF aka PFLU6122
# INFO:root:url = https://openknowledgemaps.org/map/c36c8a789de21c96416a3e84e0448a23
# INFO:root:Processing index #249 => locus tag PFLU6123
# INFO:root:Querying atpE aka PFLU6123
# INFO:root:url = https://openknowledgemaps.org/map/e1372a546c6bb76df9d37a97a48f81f6
# INFO:root:Processing index #250 => locus tag PFLU6124
# INFO:root:Querying atpB aka PFLU6124
# INFO:root:url = https://openknowledgemaps.org/map/3c6fc65ea008620a77ab8d1a0bdacf2c
# INFO:root:Processing index #251 => locus tag PFLU6127
# INFO:root:Querying parA aka PFLU6127
# INFO:root:url = https://openknowledgemaps.org/map/a87617abc148512ca50edd5a266004fa
# INFO:root:Processing index #252 => locus tag PFLU6128
# INFO:root:Querying gidB aka PFLU6128
# INFO:root:url = https://openknowledgemaps.org/map/c538975bc5d3242add7777011fb91bd5
# INFO:root:Processing index #253 => locus tag PFLU6129
# INFO:root:Querying gidA aka PFLU6129
# INFO:root:url = https://openknowledgemaps.org/map/a41e61ef3c8e8511c202e7b1a05ca170
# INFO:root:Processing index #254 => locus tag PFLU6131
# INFO:root:Querying fecR aka PFLU6131
# INFO:root:url = https://openknowledgemaps.org/map/101757daa67f5efc2b748214c2dfae31
# INFO:root:Processing index #255 => locus tag PFLU6133
# INFO:root:Querying trmE aka PFLU6133
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #256 => locus tag PFLU6135
# INFO:root:Querying rnpA aka PFLU6135
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #257 => locus tag PFLU6136
# INFO:root:Querying rpmH aka PFLU6136
# INFO:root:url = https://openknowledgemaps.org/map/77a4b060dac4f5cd97b50872d60da4bc

# %%
okm_urls.to_json("okm_urls_idx{0:d}-{1:d}.json".format(idx_lo, idx_hi))

# %%
import json

# %%
with open("okm_urls_idx0-400.json", 'r') as fp:
    tmp = json.load(fp)

okm_urls_0_400 = pandas.Series(tmp).loc[:"PFLU1295"]

# %%
with open("okm_urls_idx401-600.json", 'r') as fp:
    tmp = json.load(fp)

# %%
okm_urls_401_600 = pandas.Series(tmp)

# %%
with open("okm_urls_idx600-800.json", 'r') as fp:
    tmp = json.load(fp)

# %%
okm_urls_600_800 = pandas.Series(tmp)

# %%
with open("okm_urls_idx800-1058.json", 'r') as fp:
    tmp = json.load(fp)

okm_urls_800_1058 = pandas.Series(tmp)

# %%
okm_urls_0_400.index[-1]
# Out:
# 'PFLU1295'

# %%
print(okm_urls_401_600.index[0], okm_urls_401_600.index[-1])
# Out:
# PFLU1295 PFLU2520

# %%
print(okm_urls_600_800.index[0], okm_urls_600_800.index[-1])
# Out:
# PFLU2521 PFLU5339

# %%
print(okm_urls_800_1058.index[0], okm_urls_800_1058.index[-1])
# Out:
# PFLU5340 PFLU6136

# %%
okm_urls = pandas.concat([okm_urls_0_400.iloc[:-1], okm_urls_401_600, okm_urls_600_800, okm_urls_800_1058], axis=0)

# %%
okm_urls['PFLU0382']
# Out:
# 'https://openknowledgemaps.org/map/d3ae8d00b1401f0bb1cec12afd34a86c'

# %%
okm_urls.to_json("pflu_okm_urls_20190424.json")
