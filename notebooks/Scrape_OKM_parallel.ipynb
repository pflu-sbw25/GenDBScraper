# %% [markdown]
# # Get knowledge maps for all genes in SBW25

# %%
idx_lo = 401
idx_hi = 600

# %%
import pandas, numpy

from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions
import logging

# %%
def query_okm(idx):

    gene = gene_names.loc[idx]
    logging.info("Querying %s aka %s", gene, idx)
    search_box = driver.find_element_by_id("searchterm")
    search_box.clear()
    search_box.send_keys(gene)
                         
    search_box.submit()
    
    driver.switch_to.window(window_name=driver.window_handles[1])
    
    try:
        element = WebDriverWait(driver, 60).until(
            expected_conditions.presence_of_element_located((By.ID, "chart_canvas"))
        )
    
        okm_url = driver.current_url
        
        
        logging.info("url = %s", okm_url)
        
     
    
    except:
        logging.error("No map found after waiting for 60 seconds")
        
        okm_url = None
       
        
    finally:
        driver.close()
        driver.switch_to.window(window_name=driver.window_handles[0])
        
        return okm_url

# %%
logging.getLogger().setLevel(logging.INFO)

# %%
features = pandas.read_csv("/opt/data/sbw25/features.csv")

# %%
gene_names = features["Gene Name"]

gene_names.index = features["Locus Tag"]

non_nan_tags = [t for t in gene_names.index if isinstance(gene_names.loc[t], str)]

gene_names = gene_names.loc[non_nan_tags]

gene_names = gene_names.iloc[idx_lo:idx_hi]

# %%
okm_urls = pandas.Series(index = gene_names.index, data=[None]*len(gene_names))

# %%
driver = webdriver.Firefox()

# %%
driver.get('https://openknowledgemaps.org')

# %% [markdown]
# ### Break here

# %%
for i,locus_tag in enumerate(gene_names.index):
    logging.info("Processing index #%d => locus tag %s", i, locus_tag)
    okm_urls.loc[locus_tag] = query_okm(locus_tag)
# Out:
# INFO:root:Processing index #0 => locus tag PFLU1295
# INFO:root:Querying adhC aka PFLU1295
# INFO:root:url = https://openknowledgemaps.org/map/567cbe59b3841c280982a7043665250e
# INFO:root:Processing index #1 => locus tag PFLU1297
# INFO:root:Querying ispF aka PFLU1297
# INFO:root:url = https://openknowledgemaps.org/map/9910ffe0172f0fcfab1b76f162c4df53
# INFO:root:Processing index #2 => locus tag PFLU1298
# INFO:root:Querying truD aka PFLU1298
# INFO:root:url = https://openknowledgemaps.org/map/b239916e091e477cf2fa6b2bb3dc9f4c
# INFO:root:Processing index #3 => locus tag PFLU1299
# INFO:root:Querying surE aka PFLU1299
# INFO:root:url = https://openknowledgemaps.org/map/7aa588f3425d69d05a25d139c5aefa78
# INFO:root:Processing index #4 => locus tag PFLU1300
# INFO:root:Querying pcm aka PFLU1300
# INFO:root:url = https://openknowledgemaps.org/map/2412d13c15879a17b2e5cceecca31bec
# INFO:root:Processing index #5 => locus tag PFLU1302
# INFO:root:Querying rpoS aka PFLU1302
# INFO:root:url = https://openknowledgemaps.org/map/8da245d497041fe22fcaaf125ef73528
# INFO:root:Processing index #6 => locus tag PFLU1302A
# INFO:root:Querying capB aka PFLU1302A
# INFO:root:url = https://openknowledgemaps.org/map/084ade70b5132cf550d4c392c396a52f
# INFO:root:Processing index #7 => locus tag PFLU1307
# INFO:root:Querying aotP aka PFLU1307
# INFO:root:url = https://openknowledgemaps.org/map/53c0d33de84346a42b872adb16d0ce82
# INFO:root:Processing index #8 => locus tag PFLU1309
# INFO:root:Querying hisM aka PFLU1309
# INFO:root:url = https://openknowledgemaps.org/map/5737787e195307a5f6fd5fbc8b33a100
# INFO:root:Processing index #9 => locus tag PFLU1310
# INFO:root:Querying hisQ aka PFLU1310
# INFO:root:url = https://openknowledgemaps.org/map/f99caf99ac2b4b57e01d9639049e3f36
# INFO:root:Processing index #10 => locus tag PFLU1324
# INFO:root:Querying dinG aka PFLU1324
# INFO:root:url = https://openknowledgemaps.org/map/66339091e150021c83bc846594cdc2fa
# INFO:root:Processing index #11 => locus tag PFLU1326
# INFO:root:Querying estC aka PFLU1326
# INFO:root:url = https://openknowledgemaps.org/map/45da9b8e294c0ce19a914301ad87c030
# INFO:root:Processing index #12 => locus tag PFLU1328
# INFO:root:Querying pdxH aka PFLU1328
# INFO:root:url = https://openknowledgemaps.org/map/9bb48f51f04559468169dcdd70ec7c6d
# INFO:root:Processing index #13 => locus tag PFLU1332
# INFO:root:Querying nhaA aka PFLU1332
# INFO:root:url = https://openknowledgemaps.org/map/bf288a311ece906e904c451d14699fe8
# INFO:root:Processing index #14 => locus tag PFLU1342
# INFO:root:Querying livF1 aka PFLU1342
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #15 => locus tag PFLU1343
# INFO:root:Querying livG aka PFLU1343
# INFO:root:url = https://openknowledgemaps.org/map/6b97b0467af0885e17895021f0000a88
# INFO:root:Processing index #16 => locus tag PFLU1344
# INFO:root:Querying livM aka PFLU1344
# INFO:root:url = https://openknowledgemaps.org/map/cf4f26d609946e19a592e409a9a27055
# INFO:root:Processing index #17 => locus tag PFLU1345
# INFO:root:Querying livH1 aka PFLU1345
# INFO:root:url = https://openknowledgemaps.org/map/05a1e75d81dbd27845f12bf89c0e2e15
# INFO:root:Processing index #18 => locus tag PFLU1346
# INFO:root:Querying livJ1 aka PFLU1346
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #19 => locus tag PFLU1352
# INFO:root:Querying rapA aka PFLU1352
# INFO:root:url = https://openknowledgemaps.org/map/74c4434d23ca577383351ef3bbcff773
# INFO:root:Processing index #20 => locus tag PFLU1359
# INFO:root:Querying pitA aka PFLU1359
# INFO:root:url = https://openknowledgemaps.org/map/6057c63724bad9061364290c6edf5e28
# INFO:root:Processing index #21 => locus tag PFLU1361
# INFO:root:Querying pcaR aka PFLU1361
# INFO:root:url = https://openknowledgemaps.org/map/8b6fae6fb32afe2351f8a0e1ba937355
# INFO:root:Processing index #22 => locus tag PFLU1362
# INFO:root:Querying pcaK aka PFLU1362
# INFO:root:url = https://openknowledgemaps.org/map/1ca4bcc2ed48ef89d05b9d2de0de6947
# INFO:root:Processing index #23 => locus tag PFLU1364
# INFO:root:Querying gctB aka PFLU1364
# INFO:root:url = https://openknowledgemaps.org/map/c79daa4a92306421a6a965d7a54950c1
# INFO:root:Processing index #24 => locus tag PFLU1365
# INFO:root:Querying pcaF aka PFLU1365
# INFO:root:url = https://openknowledgemaps.org/map/e60771e02176acbddb35c2017ac4b120
# INFO:root:Processing index #25 => locus tag PFLU1366
# INFO:root:Querying pcaH aka PFLU1366
# INFO:root:url = https://openknowledgemaps.org/map/ab72b4c65a14b206862dc21eecb481fb
# INFO:root:Processing index #26 => locus tag PFLU1367
# INFO:root:Querying pcaG aka PFLU1367
# INFO:root:url = https://openknowledgemaps.org/map/62af1738d90a3aecd4bec7eb0d5f7efc
# INFO:root:Processing index #27 => locus tag PFLU1368
# INFO:root:Querying kgtP aka PFLU1368
# INFO:root:url = https://openknowledgemaps.org/map/89355f153cb0b67d5107eaa129eddeb5
# INFO:root:Processing index #28 => locus tag PFLU1369
# INFO:root:Querying pcaB aka PFLU1369
# INFO:root:url = https://openknowledgemaps.org/map/9f0c290dfdc9a9c56441e925d5ac28c8
# INFO:root:Processing index #29 => locus tag PFLU1371
# INFO:root:Querying pcaC aka PFLU1371
# INFO:root:url = https://openknowledgemaps.org/map/d6d59d3ac81961f46cf6dbbf70b4681c
# INFO:root:Processing index #30 => locus tag PFLU1377
# INFO:root:Querying hscC aka PFLU1377
# INFO:root:url = https://openknowledgemaps.org/map/b65d7118c856189cb997ca0cf7553542
# INFO:root:Processing index #31 => locus tag PFLU1378
# INFO:root:Querying oprM aka PFLU1378
# INFO:root:url = https://openknowledgemaps.org/map/756ed3b8831d6abcb3a3015cdb727f09
# INFO:root:Processing index #32 => locus tag PFLU1379
# INFO:root:Querying acrB aka PFLU1379
# INFO:root:url = https://openknowledgemaps.org/map/0fc113455db0aa7e55d5e5509a30d5ce
# INFO:root:Processing index #33 => locus tag PFLU1380
# INFO:root:Querying acrA aka PFLU1380
# INFO:root:url = https://openknowledgemaps.org/map/9380dacd1e4b1daef76b0bc79a99e51c
# INFO:root:Processing index #34 => locus tag PFLU1385
# INFO:root:Querying trpG aka PFLU1385
# INFO:root:url = https://openknowledgemaps.org/map/d82c0e55c5c8f499eed309e7daffe328
# INFO:root:Processing index #35 => locus tag PFLU1399
# INFO:root:Querying bglX aka PFLU1399
# INFO:root:url = https://openknowledgemaps.org/map/769fa9b12ad6916573ddbdf31bd66950
# INFO:root:Processing index #36 => locus tag PFLU1421
# INFO:root:Querying fosA aka PFLU1421
# INFO:root:url = https://openknowledgemaps.org/map/c8b9bbece645a69523ed5616ae478eb2
# INFO:root:Processing index #37 => locus tag PFLU1425
# INFO:root:Querying ogt aka PFLU1425
# INFO:root:url = https://openknowledgemaps.org/map/7d7223903aaba8d2572e68604474283a
# INFO:root:Processing index #38 => locus tag PFLU1434
# INFO:root:Querying phaG aka PFLU1434
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #39 => locus tag PFLU1436
# INFO:root:Querying rsuA aka PFLU1436
# INFO:root:url = https://openknowledgemaps.org/map/918019b05d93ad6bdec807ab5b3c03dd
# INFO:root:Processing index #40 => locus tag PFLU1441
# INFO:root:Querying ung aka PFLU1441
# INFO:root:url = https://openknowledgemaps.org/map/7d7ea0c0ea493f5fe54bd637c78f2b4b
# INFO:root:Processing index #41 => locus tag PFLU1451
# INFO:root:Querying tctD aka PFLU1451
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #42 => locus tag PFLU1465
# INFO:root:Querying nadB aka PFLU1465
# INFO:root:url = https://openknowledgemaps.org/map/b750285baeb23f0ae0b1da5557b55764
# INFO:root:Processing index #43 => locus tag PFLU1467
# INFO:root:Querying algU aka PFLU1467
# INFO:root:url = https://openknowledgemaps.org/map/de66e40fc48b7a8e1fdfeea5f1009fca
# INFO:root:Processing index #44 => locus tag PFLU1468
# INFO:root:Querying mucA aka PFLU1468
# INFO:root:url = https://openknowledgemaps.org/map/0e082d2b0d756ce24b8356ee6d4560e9
# INFO:root:Processing index #45 => locus tag PFLU1469
# INFO:root:Querying mucB aka PFLU1469
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #46 => locus tag PFLU1474
# INFO:root:Querying perM aka PFLU1474
# INFO:root:url = https://openknowledgemaps.org/map/8dea01a89a689c9ed70d838929eacafb
# INFO:root:Processing index #47 => locus tag PFLU1477
# INFO:root:Querying dapA aka PFLU1477
# INFO:root:url = https://openknowledgemaps.org/map/6b68be8e92d7de210a003c98a29849f3
# INFO:root:Processing index #48 => locus tag PFLU1480
# INFO:root:Querying purC aka PFLU1480
# INFO:root:url = https://openknowledgemaps.org/map/e7c33e3b70b8af6841cf6d1e0f5ebb61
# INFO:root:Processing index #49 => locus tag PFLU1489
# INFO:root:Querying citA aka PFLU1489
# INFO:root:url = https://openknowledgemaps.org/map/3e18b95edf9866d61f7d9e7d1d41094b
# INFO:root:Processing index #50 => locus tag PFLU1510
# INFO:root:Querying pobA aka PFLU1510
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #51 => locus tag PFLU1513
# INFO:root:Querying pheC aka PFLU1513
# INFO:root:url = https://openknowledgemaps.org/map/156153aeca0546e2e332918cab3df3d8
# INFO:root:Processing index #52 => locus tag PFLU1540
# INFO:root:Querying cysK aka PFLU1540
# INFO:root:url = https://openknowledgemaps.org/map/887477c6ba221799822ffff5f3dac584
# INFO:root:Processing index #53 => locus tag PFLU1542
# INFO:root:Querying acnA aka PFLU1542
# INFO:root:url = https://openknowledgemaps.org/map/a4080863b319bac563c920deaaaf1df2
# INFO:root:Processing index #54 => locus tag PFLU1545
# INFO:root:Querying norM aka PFLU1545
# INFO:root:url = https://openknowledgemaps.org/map/0ddf46dcb3ae6155d6770282d9481ad4
# INFO:root:Processing index #55 => locus tag PFLU1546
# INFO:root:Querying pdxB aka PFLU1546
# INFO:root:url = https://openknowledgemaps.org/map/92f89a52d960842b839500d459b09416
# INFO:root:Processing index #56 => locus tag PFLU1553
# INFO:root:Querying fadB aka PFLU1553
# INFO:root:url = https://openknowledgemaps.org/map/25955bb205498c871e9c2ad3d106b614
# INFO:root:Processing index #57 => locus tag PFLU1554
# INFO:root:Querying fadA aka PFLU1554
# INFO:root:url = https://openknowledgemaps.org/map/4fdfa7cbe78c26a3b007516486a56ce8
# INFO:root:Processing index #58 => locus tag PFLU1556
# INFO:root:Querying topA aka PFLU1556
# INFO:root:url = https://openknowledgemaps.org/map/568f5d833de8385166018c3a60d60cbe
# INFO:root:Processing index #59 => locus tag PFLU1560
# INFO:root:Querying lexA aka PFLU1560
# INFO:root:url = https://openknowledgemaps.org/map/04d3c2c1066942d08cd740447c0039df
# INFO:root:Processing index #60 => locus tag PFLU1562
# INFO:root:Querying nagZ aka PFLU1562
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #61 => locus tag PFLU1565
# INFO:root:Querying mfd aka PFLU1565
# INFO:root:url = https://openknowledgemaps.org/map/805042c819c3ceef5f24b9a58bab37a8
# INFO:root:Processing index #62 => locus tag PFLU1566
# INFO:root:Querying gap aka PFLU1566
# INFO:root:url = https://openknowledgemaps.org/map/62a47b5f074ce277c11f320fdf5ef1d6
# INFO:root:Processing index #63 => locus tag PFLU1569
# INFO:root:Querying sthA aka PFLU1569
# INFO:root:url = https://openknowledgemaps.org/map/cb7d0f836a503b3bf9289025bc3422e9
# INFO:root:Processing index #64 => locus tag PFLU1573
# INFO:root:Querying lolD aka PFLU1573
# INFO:root:url = https://openknowledgemaps.org/map/457982535c84d6bea0ce8803b377eca6
# INFO:root:Processing index #65 => locus tag PFLU1576
# INFO:root:Querying cusR aka PFLU1576
# INFO:root:url = https://openknowledgemaps.org/map/62c90493e4672ff982384e8b83940446
# INFO:root:Processing index #66 => locus tag PFLU1578
# INFO:root:Querying queF aka PFLU1578
# INFO:root:url = https://openknowledgemaps.org/map/9fcecd98f56003c0b0b0e38bedc80417
# INFO:root:Processing index #67 => locus tag PFLU1585
# INFO:root:Querying talB aka PFLU1585
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #68 => locus tag PFLU1586
# INFO:root:Querying dusA aka PFLU1586
# INFO:root:url = https://openknowledgemaps.org/map/e465e9b4ea27c6bd5c44c18605887c40
# INFO:root:Processing index #69 => locus tag PFLU1613
# INFO:root:Querying mqo aka PFLU1613
# INFO:root:url = https://openknowledgemaps.org/map/85cdb209f618a21058134d1b76ad1461
# INFO:root:Processing index #70 => locus tag PFLU1624
# INFO:root:Querying argD aka PFLU1624
# INFO:root:url = https://openknowledgemaps.org/map/b0edce8e941bd387fc82faa82e6ab9d5
# INFO:root:Processing index #71 => locus tag PFLU1639
# INFO:root:Querying ubiG aka PFLU1639
# INFO:root:url = https://openknowledgemaps.org/map/92c2348b1891292b0cc84abac11e2ae6
# INFO:root:Processing index #72 => locus tag PFLU1641
# INFO:root:Querying mtnA aka PFLU1641
# INFO:root:url = https://openknowledgemaps.org/map/c894290066b526d0243e3091be2b31eb
# INFO:root:Processing index #73 => locus tag PFLU1643
# INFO:root:Querying gyrA aka PFLU1643
# INFO:root:url = https://openknowledgemaps.org/map/c385add4dd08e7a76586bdcf30844e85
# INFO:root:Processing index #74 => locus tag PFLU1644
# INFO:root:Querying serC aka PFLU1644
# INFO:root:url = https://openknowledgemaps.org/map/6ec6fa37b9c1874f3d96b53c5d9b6e64
# INFO:root:Processing index #75 => locus tag PFLU1645
# INFO:root:Querying pheA aka PFLU1645
# INFO:root:url = https://openknowledgemaps.org/map/5aefb3f585acea04a6d9a17032461675
# INFO:root:Processing index #76 => locus tag PFLU1646
# INFO:root:Querying hisC aka PFLU1646
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #77 => locus tag PFLU1648
# INFO:root:Querying cmk aka PFLU1648
# INFO:root:url = https://openknowledgemaps.org/map/b30bac2f731673a13a9323dd76926a47
# INFO:root:Processing index #78 => locus tag PFLU1649
# INFO:root:Querying rpsA aka PFLU1649
# INFO:root:url = https://openknowledgemaps.org/map/35964da40776d0502a865a1fcaedd218
# INFO:root:Processing index #79 => locus tag PFLU1651
# INFO:root:Querying ihfB aka PFLU1651
# INFO:root:url = https://openknowledgemaps.org/map/ead3f5190992b59eb598b930a8d18e1f
# INFO:root:Processing index #80 => locus tag PFLU1657
# INFO:root:Querying fnl1 aka PFLU1657
# INFO:root:url = https://openknowledgemaps.org/map/9ce9e8ccf501b73a9a10ba1497957c76
# INFO:root:Processing index #81 => locus tag PFLU1658
# INFO:root:Querying fnl2 aka PFLU1658
# INFO:root:url = https://openknowledgemaps.org/map/901895ad4f35c9df0e5a9a96f549bfb2
# INFO:root:Processing index #82 => locus tag PFLU1659
# INFO:root:Querying fnl3 aka PFLU1659
# INFO:root:url = https://openknowledgemaps.org/map/e23ab252c66040155532a4903fc03ed1
# INFO:root:Processing index #83 => locus tag PFLU1676
# INFO:root:Querying kdpA aka PFLU1676
# INFO:root:url = https://openknowledgemaps.org/map/b544560f44f9643fc7458b2c62356e13
# INFO:root:Processing index #84 => locus tag PFLU1677
# INFO:root:Querying kdpB aka PFLU1677
# INFO:root:url = https://openknowledgemaps.org/map/6d3ef6e1816e90b658abc33150e5027b
# INFO:root:Processing index #85 => locus tag PFLU1678
# INFO:root:Querying kdpC aka PFLU1678
# INFO:root:url = https://openknowledgemaps.org/map/a7cda9244e524388f35ba1a876e43c7f
# INFO:root:Processing index #86 => locus tag PFLU1679
# INFO:root:Querying kdpD aka PFLU1679
# INFO:root:url = https://openknowledgemaps.org/map/fe92cfb7b44fecbcfcfad8cdfe8d50d8
# INFO:root:Processing index #87 => locus tag PFLU1680
# INFO:root:Querying kdpE aka PFLU1680
# INFO:root:url = https://openknowledgemaps.org/map/bc4dcd8c1656e3920dfdb63723b334f2
# INFO:root:Processing index #88 => locus tag PFLU1696
# INFO:root:Querying greB aka PFLU1696
# INFO:root:url = https://openknowledgemaps.org/map/0196377ea54b714cde4347a2ea73321c
# INFO:root:Processing index #89 => locus tag PFLU1702
# INFO:root:Querying oprI aka PFLU1702
# INFO:root:url = https://openknowledgemaps.org/map/50b1c6df8601a21d9aba13f650694442
# INFO:root:Processing index #90 => locus tag PFLU1704
# INFO:root:Querying aroG aka PFLU1704
# INFO:root:url = https://openknowledgemaps.org/map/01c7ac6a403d1eea52fff2a0200e00ef
# INFO:root:Processing index #91 => locus tag PFLU1710
# INFO:root:Querying cysB aka PFLU1710
# INFO:root:url = https://openknowledgemaps.org/map/e0341dce0009665302633bd9aafae234
# INFO:root:Processing index #92 => locus tag PFLU1716
# INFO:root:Querying ohrB aka PFLU1716
# INFO:root:url = https://openknowledgemaps.org/map/58f1374da2ffcd12a0d7956da459e2b5
# INFO:root:Processing index #93 => locus tag PFLU1717
# INFO:root:Querying ohrR aka PFLU1717
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #94 => locus tag PFLU1723
# INFO:root:Querying aroH aka PFLU1723
# INFO:root:url = https://openknowledgemaps.org/map/3e6a9cd7c2efa65186dec7b6705d327d
# INFO:root:Processing index #95 => locus tag PFLU1726
# INFO:root:Querying deaD aka PFLU1726
# INFO:root:url = https://openknowledgemaps.org/map/3dec670b446c0c61751f67d51be9ba4a
# INFO:root:Processing index #96 => locus tag PFLU1728
# INFO:root:Querying tpm aka PFLU1728
# INFO:root:url = https://openknowledgemaps.org/map/8036f3e96f6d96be60c2b6bbf471be60
# INFO:root:Processing index #97 => locus tag PFLU1730
# INFO:root:Querying htpX aka PFLU1730
# INFO:root:url = https://openknowledgemaps.org/map/28215860a79fb1950e0a945a06ef9411
# INFO:root:Processing index #98 => locus tag PFLU1732
# INFO:root:Querying msrB aka PFLU1732
# INFO:root:url = https://openknowledgemaps.org/map/6438c2a4251d135c5748396c9917134c
# INFO:root:Processing index #99 => locus tag PFLU1734
# INFO:root:Querying gpx1 aka PFLU1734
# INFO:root:url = https://openknowledgemaps.org/map/2a9700bff2ad5bbea23a18a7267df401
# INFO:root:Processing index #100 => locus tag PFLU1753
# INFO:root:Querying mobA aka PFLU1753
# INFO:root:url = https://openknowledgemaps.org/map/ccf86c5a15bc86c733614821e886ee05
# INFO:root:Processing index #101 => locus tag PFLU1754
# INFO:root:Querying moaB aka PFLU1754
# INFO:root:url = https://openknowledgemaps.org/map/de7ca6810a7bb03a5d039b9f3cb36769
# INFO:root:Processing index #102 => locus tag PFLU1755
# INFO:root:Querying moeA aka PFLU1755
# INFO:root:url = https://openknowledgemaps.org/map/6b92098af7c4e3524ffb3aedcfa2319f
# INFO:root:Processing index #103 => locus tag PFLU1758
# INFO:root:Querying ccmA aka PFLU1758
# INFO:root:url = https://openknowledgemaps.org/map/281c09401c807666a6eb8360c86a90bc
# INFO:root:Processing index #104 => locus tag PFLU1759
# INFO:root:Querying ccmB aka PFLU1759
# INFO:root:url = https://openknowledgemaps.org/map/af3199d71861d99d0c54ed08b2d681a6
# INFO:root:Processing index #105 => locus tag PFLU1760
# INFO:root:Querying ccmC aka PFLU1760
# INFO:root:url = https://openknowledgemaps.org/map/6424581d1b387cfb71230e42d63d36f8
# INFO:root:Processing index #106 => locus tag PFLU1761
# INFO:root:Querying ccmD aka PFLU1761
# INFO:root:url = https://openknowledgemaps.org/map/89baf18fd80f3dbb30403cc30a7c4b6a
# INFO:root:Processing index #107 => locus tag PFLU1762
# INFO:root:Querying ccmE aka PFLU1762
# INFO:root:url = https://openknowledgemaps.org/map/f1ff77c321c7e11c4ab13ed78086c2b3
# INFO:root:Processing index #108 => locus tag PFLU1763
# INFO:root:Querying ccmF aka PFLU1763
# INFO:root:url = https://openknowledgemaps.org/map/1f5f7387c574069bed85e29d4accccc8
# INFO:root:Processing index #109 => locus tag PFLU1764
# INFO:root:Querying dsbE aka PFLU1764
# INFO:root:url = https://openknowledgemaps.org/map/85c13e174b871203eb954b3c544ddb0b
# INFO:root:Processing index #110 => locus tag PFLU1765
# INFO:root:Querying ccmH aka PFLU1765
# INFO:root:url = https://openknowledgemaps.org/map/f719a6dbbb710be261a20ea1f5bdcd73
# INFO:root:Processing index #111 => locus tag PFLU1777
# INFO:root:Querying phnC aka PFLU1777
# INFO:root:url = https://openknowledgemaps.org/map/b616e7d86a80ce6737e6bbaab88ca60a
# INFO:root:Processing index #112 => locus tag PFLU1778
# INFO:root:Querying phnD aka PFLU1778
# INFO:root:url = https://openknowledgemaps.org/map/f00cc09ed4a9aac9ecb4004832c8603a
# INFO:root:Processing index #113 => locus tag PFLU1779
# INFO:root:Querying phnE aka PFLU1779
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #114 => locus tag PFLU1782
# INFO:root:Querying phnH aka PFLU1782
# INFO:root:url = https://openknowledgemaps.org/map/1a94bd70a8cf68e842e876dbd26bb506
# INFO:root:Processing index #115 => locus tag PFLU1783
# INFO:root:Querying phnI aka PFLU1783
# INFO:root:url = https://openknowledgemaps.org/map/71b6af8a34af07b9d0864be220684e46
# INFO:root:Processing index #116 => locus tag PFLU1784
# INFO:root:Querying phnJ aka PFLU1784
# INFO:root:url = https://openknowledgemaps.org/map/d8c9a925dca6816d4683417ab7571158
# INFO:root:Processing index #117 => locus tag PFLU1785
# INFO:root:Querying phnK aka PFLU1785
# INFO:root:url = https://openknowledgemaps.org/map/02ca6f0928d08ae19fdd129352b60fc8
# INFO:root:Processing index #118 => locus tag PFLU1786
# INFO:root:Querying phnL aka PFLU1786
# INFO:root:url = https://openknowledgemaps.org/map/10c52102f5b533af9cac2b4af149259e
# INFO:root:Processing index #119 => locus tag PFLU1787
# INFO:root:Querying phnM aka PFLU1787
# INFO:root:url = https://openknowledgemaps.org/map/d44e606c1d18205721aede22ea36399b
# INFO:root:Processing index #120 => locus tag PFLU1788
# INFO:root:Querying phnN aka PFLU1788
# INFO:root:url = https://openknowledgemaps.org/map/c80f0a42a4a0d77d7dfce1de7b265d2f
# INFO:root:Processing index #121 => locus tag PFLU1789
# INFO:root:Querying phnP aka PFLU1789
# INFO:root:url = https://openknowledgemaps.org/map/48d0bc23ef9ec7fc8d42dba41090871e
# INFO:root:Processing index #122 => locus tag PFLU1796
# INFO:root:Querying sbp aka PFLU1796
# INFO:root:url = https://openknowledgemaps.org/map/b9e304eb127ebb64c2582c0430ac9b48
# INFO:root:Processing index #123 => locus tag PFLU1799
# INFO:root:Querying pyk aka PFLU1799
# INFO:root:url = https://openknowledgemaps.org/map/64e7c8751f78f1f3040e83d608080c33
# INFO:root:Processing index #124 => locus tag PFLU1801
# INFO:root:Querying glxR aka PFLU1801
# INFO:root:url = https://openknowledgemaps.org/map/62ed0863289595138029f62616ad86ba
# INFO:root:Processing index #125 => locus tag PFLU1802
# INFO:root:Querying hyi aka PFLU1802
# INFO:root:url = https://openknowledgemaps.org/map/8e10526e3d2535b81993f007cdc4f005
# INFO:root:Processing index #126 => locus tag PFLU1803
# INFO:root:Querying gcl aka PFLU1803
# INFO:root:url = https://openknowledgemaps.org/map/d6afafa2e055dc1772f9df72bea3a231
# INFO:root:Processing index #127 => locus tag PFLU1814
# INFO:root:Querying actP aka PFLU1814
# INFO:root:url = https://openknowledgemaps.org/map/a6fab5bd6e46431611fd3a013eec0a82
# INFO:root:Processing index #128 => locus tag PFLU1815
# INFO:root:Querying gltA aka PFLU1815
# INFO:root:url = https://openknowledgemaps.org/map/e9b6997d1090357c162eac6c01f6e1d4
# INFO:root:Processing index #129 => locus tag PFLU1816
# INFO:root:Querying sdhC aka PFLU1816
# INFO:root:url = https://openknowledgemaps.org/map/f946a63eee8d4c14e0ebe812004c0442
# INFO:root:Processing index #130 => locus tag PFLU1818
# INFO:root:Querying sdhA aka PFLU1818
# INFO:root:url = https://openknowledgemaps.org/map/f45457bbaf91118e7df20824af48a0b2
# INFO:root:Processing index #131 => locus tag PFLU1819
# INFO:root:Querying sdhB aka PFLU1819
# INFO:root:url = https://openknowledgemaps.org/map/356b7cd746ed599c31a9bfdf8cfd2277
# INFO:root:Processing index #132 => locus tag PFLU1820
# INFO:root:Querying sucA aka PFLU1820
# INFO:root:url = https://openknowledgemaps.org/map/b73940f916b70bf63fc4b650a9024106
# INFO:root:Processing index #133 => locus tag PFLU1821
# INFO:root:Querying sucB aka PFLU1821
# INFO:root:url = https://openknowledgemaps.org/map/df0573427078bf2f5028b4d1495801e8
# INFO:root:Processing index #134 => locus tag PFLU1822
# INFO:root:Querying lpd aka PFLU1822
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #135 => locus tag PFLU1823
# INFO:root:Querying sucC aka PFLU1823
# INFO:root:url = https://openknowledgemaps.org/map/8db4b344d766b9e0a1a93556aade8392
# INFO:root:Processing index #136 => locus tag PFLU1824
# INFO:root:Querying sucD aka PFLU1824
# INFO:root:url = https://openknowledgemaps.org/map/f6ea58288b96db744599261cf336ba85
# INFO:root:Processing index #137 => locus tag PFLU1825
# INFO:root:Querying brnQ aka PFLU1825
# INFO:root:url = https://openknowledgemaps.org/map/d0012dc8e594470aff11a88f24a3db70
# INFO:root:Processing index #138 => locus tag PFLU1830
# INFO:root:Querying htpG aka PFLU1830
# INFO:root:url = https://openknowledgemaps.org/map/cd44f475ef71608c1e100bee03a1f8b1
# INFO:root:Processing index #139 => locus tag PFLU1835
# INFO:root:Querying fabB aka PFLU1835
# INFO:root:url = https://openknowledgemaps.org/map/852ce0653084ec39a15fae85db92f298
# INFO:root:Processing index #140 => locus tag PFLU1836
# INFO:root:Querying fabA aka PFLU1836
# INFO:root:url = https://openknowledgemaps.org/map/0e273a16766a6f3a7c4d55ff3395187d
# INFO:root:Processing index #141 => locus tag PFLU1840
# INFO:root:Querying gpsA aka PFLU1840
# INFO:root:url = https://openknowledgemaps.org/map/343b778c0f27f4d507c6928189b91d54
# INFO:root:Processing index #142 => locus tag PFLU1851
# INFO:root:Querying pyrF aka PFLU1851
# INFO:root:url = https://openknowledgemaps.org/map/87e4d34982c5de3f1217d02e8547dc63
# INFO:root:Processing index #143 => locus tag PFLU1865
# INFO:root:Querying fadE aka PFLU1865
# INFO:root:url = https://openknowledgemaps.org/map/0c2ca273d8b0505d1e314e147acdd29b
# INFO:root:Processing index #144 => locus tag PFLU1875
# INFO:root:Querying sugE aka PFLU1875
# INFO:root:url = https://openknowledgemaps.org/map/b4b6c2ee8e9e9b95686f14cfd06a36be
# INFO:root:Processing index #145 => locus tag PFLU1877
# INFO:root:Querying rdgC aka PFLU1877
# INFO:root:url = https://openknowledgemaps.org/map/9f274812d92206ee0559159ad29caea6
# INFO:root:Processing index #146 => locus tag PFLU1902
# INFO:root:Querying ppa aka PFLU1902
# INFO:root:url = https://openknowledgemaps.org/map/54ef0f6bc11229a2a153627413e83d2e
# INFO:root:Processing index #147 => locus tag PFLU1903
# INFO:root:Querying eno aka PFLU1903
# INFO:root:url = https://openknowledgemaps.org/map/244c2b4230f84c9a64db2328a404a391
# INFO:root:Processing index #148 => locus tag PFLU1938
# INFO:root:Querying gabD2 aka PFLU1938
# INFO:root:url = https://openknowledgemaps.org/map/086d174d2fb5846db8ecdb73a0fc4363
# INFO:root:Processing index #149 => locus tag PFLU1947
# INFO:root:Querying nodD aka PFLU1947
# INFO:root:url = https://openknowledgemaps.org/map/decc0af5ef2b60a10a9cf99395e96131
# INFO:root:Processing index #150 => locus tag PFLU1972
# INFO:root:Querying topB aka PFLU1972
# INFO:root:url = https://openknowledgemaps.org/map/b03e45645b9e820b1db3060d7bd56f77
# INFO:root:Processing index #151 => locus tag PFLU1997
# INFO:root:Querying accC aka PFLU1997
# INFO:root:url = https://openknowledgemaps.org/map/028dee0e4c73b580f41a0568df330d2a
# INFO:root:Processing index #152 => locus tag PFLU2013
# INFO:root:Querying cycA aka PFLU2013
# INFO:root:url = https://openknowledgemaps.org/map/faec42c0e31cb84bbe31c9a01fe15c7b
# INFO:root:Processing index #153 => locus tag PFLU2027
# INFO:root:Querying fklB aka PFLU2027
# INFO:root:url = https://openknowledgemaps.org/map/6ab4df4f9dcee013da3e82675d5f082d
# INFO:root:Processing index #154 => locus tag PFLU2032
# INFO:root:Querying prc aka PFLU2032
# INFO:root:url = https://openknowledgemaps.org/map/fedb50232441e0134de5eba24b818e5b
# INFO:root:Processing index #155 => locus tag PFLU2049
# INFO:root:Querying leuC aka PFLU2049
# INFO:root:url = https://openknowledgemaps.org/map/b45ff0c2511469219d7fa67110a8e194
# INFO:root:Processing index #156 => locus tag PFLU2050
# INFO:root:Querying leuD aka PFLU2050
# INFO:root:url = https://openknowledgemaps.org/map/0d9fb68ca0fdd7d2aa23a4b7d58abd4c
# INFO:root:Processing index #157 => locus tag PFLU2053
# INFO:root:Querying soxR aka PFLU2053
# INFO:root:url = https://openknowledgemaps.org/map/a6ffce7480ba5e4e99c7d5616a4e5606
# INFO:root:Processing index #158 => locus tag PFLU2057
# INFO:root:Querying ssuD aka PFLU2057
# INFO:root:url = https://openknowledgemaps.org/map/9418b6143c51a8074ec32341870ca20d
# INFO:root:Processing index #159 => locus tag PFLU2060
# INFO:root:Querying iscS aka PFLU2060
# INFO:root:url = https://openknowledgemaps.org/map/7885d1b3b9d53cc6b6eb225e0fb8b8b7
# INFO:root:Processing index #160 => locus tag PFLU2064
# INFO:root:Querying mrdA aka PFLU2064
# INFO:root:url = https://openknowledgemaps.org/map/422a021dd3bcb47795007ca93c52fd2d
# INFO:root:Processing index #161 => locus tag PFLU2067
# INFO:root:Querying polB aka PFLU2067
# INFO:root:url = https://openknowledgemaps.org/map/afa183f18c4e22b96f66d050761f6c96
# INFO:root:Processing index #162 => locus tag PFLU2097
# INFO:root:Querying cysC aka PFLU2097
# INFO:root:url = https://openknowledgemaps.org/map/6fd975ae2a91c5887e239dcf09d5936f
# INFO:root:Processing index #163 => locus tag PFLU2109
# INFO:root:Querying codA aka PFLU2109
# INFO:root:url = https://openknowledgemaps.org/map/6af015eda42a356a2bb06dbc18d6959d
# INFO:root:Processing index #164 => locus tag PFLU2111
# INFO:root:Querying codB aka PFLU2111
# INFO:root:url = https://openknowledgemaps.org/map/8a6e27c2524fb7e738c99ed87a6953e7
# INFO:root:Processing index #165 => locus tag PFLU2147
# INFO:root:Querying hemB aka PFLU2147
# INFO:root:url = https://openknowledgemaps.org/map/a379da002c6f38a25aa47ea1d237dd4b
# INFO:root:Processing index #166 => locus tag PFLU2151
# INFO:root:Querying scoB aka PFLU2151
# INFO:root:url = https://openknowledgemaps.org/map/540be0858e942b16a62c30b8c32c9076
# INFO:root:Processing index #167 => locus tag PFLU2152
# INFO:root:Querying scoA aka PFLU2152
# INFO:root:url = https://openknowledgemaps.org/map/9147cde80ea434de04a03bc9243c4923
# INFO:root:Processing index #168 => locus tag PFLU2157
# INFO:root:Querying topB aka PFLU2157
# INFO:root:url = https://openknowledgemaps.org/map/b03e45645b9e820b1db3060d7bd56f77
# INFO:root:Processing index #169 => locus tag PFLU2178
# INFO:root:Querying mgtA aka PFLU2178
# INFO:root:url = https://openknowledgemaps.org/map/46f93d01d9fc0d031651f268765bf030
# INFO:root:Processing index #170 => locus tag PFLU2183
# INFO:root:Querying dkgB aka PFLU2183
# INFO:root:url = https://openknowledgemaps.org/map/a812c1536ff160328aea246e3934c610
# INFO:root:Processing index #171 => locus tag PFLU2184
# INFO:root:Querying aroF aka PFLU2184
# INFO:root:url = https://openknowledgemaps.org/map/a577d434db50505f23feaee4793da736
# INFO:root:Processing index #172 => locus tag PFLU2189
# INFO:root:Querying gacA aka PFLU2189
# INFO:root:url = https://openknowledgemaps.org/map/dade11e6eae13fef4d7cf80458c4b9ff
# INFO:root:Processing index #173 => locus tag PFLU2190
# INFO:root:Querying uvrC aka PFLU2190
# INFO:root:url = https://openknowledgemaps.org/map/cd54abc142f557f3c945f9c6b4bf3276
# INFO:root:Processing index #174 => locus tag PFLU2191
# INFO:root:Querying pgsA aka PFLU2191
# INFO:root:url = https://openknowledgemaps.org/map/67b3dc17a7537d701ec69535f8d6d1b8
# INFO:root:Processing index #175 => locus tag PFLU2193
# INFO:root:Querying ribD aka PFLU2193
# INFO:root:url = https://openknowledgemaps.org/map/921f52ff0693a8d4487792819c03003f
# INFO:root:Processing index #176 => locus tag PFLU2264
# INFO:root:Querying gabP aka PFLU2264
# INFO:root:url = https://openknowledgemaps.org/map/2cf37b60b27c1da687d284fca0334ce5
# INFO:root:Processing index #177 => locus tag PFLU2286
# INFO:root:Querying pehX aka PFLU2286
# INFO:root:url = https://openknowledgemaps.org/map/58cf60682d1d65c44fdce29450dda483
# INFO:root:Processing index #178 => locus tag PFLU2292
# INFO:root:Querying mmsA aka PFLU2292
# INFO:root:url = https://openknowledgemaps.org/map/59eae00404ee7fe14eb66a091e008451
# INFO:root:Processing index #179 => locus tag PFLU2293
# INFO:root:Querying pnl aka PFLU2293
# INFO:root:url = https://openknowledgemaps.org/map/af119c497363aed3e272a259a72f6e4f
# INFO:root:Processing index #180 => locus tag PFLU2294
# INFO:root:Querying lsc aka PFLU2294
# INFO:root:url = https://openknowledgemaps.org/map/a95889723ce5ce832c1fe2d171428d79
# INFO:root:Processing index #181 => locus tag PFLU2298
# INFO:root:Querying xylH aka PFLU2298
# INFO:root:url = https://openknowledgemaps.org/map/510e7ad07ca764265b21261083f5ff50
# INFO:root:Processing index #182 => locus tag PFLU2299
# INFO:root:Querying xylG aka PFLU2299
# INFO:root:url = https://openknowledgemaps.org/map/bdce1838d73cc60bfbecd3dd35d8bac7
# INFO:root:Processing index #183 => locus tag PFLU2300
# INFO:root:Querying xylF aka PFLU2300
# INFO:root:url = https://openknowledgemaps.org/map/9630028024234219f6ae32f6cae8aa69
# INFO:root:Processing index #184 => locus tag PFLU2301
# INFO:root:Querying xylA aka PFLU2301
# INFO:root:url = https://openknowledgemaps.org/map/ed7835267abf20ec0a341d4d9fddadaf
# INFO:root:Processing index #185 => locus tag PFLU2302
# INFO:root:Querying xylR aka PFLU2302
# INFO:root:url = https://openknowledgemaps.org/map/966c6e67c1a4e172ba8d4130144c856e
# INFO:root:Processing index #186 => locus tag PFLU2319
# INFO:root:Querying soxB aka PFLU2319
# INFO:root:url = https://openknowledgemaps.org/map/2c13ed75d481a6b4091a4ca717ce9845
# INFO:root:Processing index #187 => locus tag PFLU2320
# INFO:root:Querying folD aka PFLU2320
# INFO:root:url = https://openknowledgemaps.org/map/94fee91798568b5b1904b23ab157a997
# INFO:root:Processing index #188 => locus tag PFLU2321
# INFO:root:Querying purU1 aka PFLU2321
# INFO:root:url = https://openknowledgemaps.org/map/0185a11d35cc0e97c393337533bec230
# INFO:root:Processing index #189 => locus tag PFLU2332
# INFO:root:Querying purU2 aka PFLU2332
# ERROR:root:No map found after waiting for 60 seconds
# INFO:root:Processing index #190 => locus tag PFLU2372
# INFO:root:Querying araF aka PFLU2372
# INFO:root:url = https://openknowledgemaps.org/map/2ff38202b6767585ab32cd04c19e5b53
# INFO:root:Processing index #191 => locus tag PFLU2373
# INFO:root:Querying araG aka PFLU2373
# INFO:root:url = https://openknowledgemaps.org/map/df440e11f75751f1e9dea4ea6e213d93
# INFO:root:Processing index #192 => locus tag PFLU2374
# INFO:root:Querying araH aka PFLU2374
# INFO:root:url = https://openknowledgemaps.org/map/8c996f7415bac99c9be718691e2d70aa
# INFO:root:Processing index #193 => locus tag PFLU2379
# INFO:root:Querying mug aka PFLU2379
# INFO:root:url = https://openknowledgemaps.org/map/6d5ccbe7444c3522712a7f0efedead3e
# INFO:root:Processing index #194 => locus tag PFLU2407
# INFO:root:Querying cpo aka PFLU2407
# INFO:root:url = https://openknowledgemaps.org/map/60e73bdf4537679a72b2de04e9d717f8
# INFO:root:Processing index #195 => locus tag PFLU2445
# INFO:root:Querying cobF aka PFLU2445
# INFO:root:url = https://openknowledgemaps.org/map/e34a15b1f9844f4bcfebca783fd65672
# INFO:root:Processing index #196 => locus tag PFLU2471
# INFO:root:Querying tsx aka PFLU2471
# INFO:root:url = https://openknowledgemaps.org/map/9c3b1127dca0358c4569aab609013a30
# INFO:root:Processing index #197 => locus tag PFLU2474
# INFO:root:Querying polS aka PFLU2474
# INFO:root:url = https://openknowledgemaps.org/map/91fbb9b84263e4fbeba8b7d91d2553ab
# INFO:root:Processing index #198 => locus tag PFLU2511
# INFO:root:Querying insC aka PFLU2511
# INFO:root:url = https://openknowledgemaps.org/map/ed4038f7d5551ee2a160a0cdc2172358
# INFO:root:Processing index #199 => locus tag PFLU2520
# INFO:root:Querying pncB aka PFLU2520
# INFO:root:url = https://openknowledgemaps.org/map/69010159527f167e675df4fd8ba5e89a

# %%
okm_urls.to_json("okm_urls_idx{0:d}-{1:d}.json".format(idx_lo, idx_hi))
